# %% [markdown]
# ## Extracting data from confluence pages

# %%
import requests
import bs4
import pandas

# %% [markdown]
# ### Data from confluence must be imported locally through html saved via element inspector

# %%
# url = "https://vcdi-dpc.atlassian.net/wiki/spaces/AKB/pages/187301909/Project+Canvas+Template"
# req = requests.get(url)
soup = bs4.BeautifulSoup(open("/users/danielcorcoran/Desktop/test_canvas.html"),"html.parser")

# %% [markdown]
# ### Inspect the soup

# %%
print(soup.prettify())
# Out:
# <div id="aui-flag-container" style="top: 20px;">
#  <div class="aui-flag-stack" data-aui-flag-stack="quickreload">
#   <div aria-hidden="true" class="aui-flag qr-flag aui-flag-stack-top-item">
#    <div class="aui-message aui-message-info info closeable shadowed">
#     <p class="title">
#      <strong>
#       New page edits
#      </strong>
#     </p>
#     <div>
#      <div class="qr-notice-authors">
#       <span class="qr-author-avatar">
#        <span class="aui-avatar aui-avatar-small">
#         <span class="aui-avatar-inner">
#          <img src="/wiki/aa-avatar/86737cb56d2cb00df0e256b57325cb09?s=48&amp;d=https%3A%2F%2Fvcdi-dpc.atlassian.net%2Fwiki%2Fimages%2Ficons%2Fprofilepics%2Fdefault.png%3FnoRedirect%3Dtrue"/>
#         </span>
#        </span>
#       </span>
#      </div>
#      <div class="qr-notice-summary">
#       <button class="aui-button aui-button-link qr-notice-show aui-button-text">
#        Reload page
#       </button>
#       <span class="qr-notice-summary-text">
#        by
#        <a class="url fn" href="/wiki/display/~sweta.patel">
#         Sweta Patel
#        </a>
#        <span class="qr-who-edit">
#        </span>
#       </span>
#      </div>
#     </div>
#     <!-- .aui-message -->
#     <span class="aui-icon icon-close" role="button" tabindex="0">
#     </span>
#    </div>
#   </div>
#  </div>
# </div>
# <div id="full-height-container">
#  <div id="header-precursor">
#   <div class="cell">
#   </div>
#  </div>
#  <div class="PageContent">
#   <script>
#    var __INITIAL_STATE__ = typeof __INITIAL_STATE__ !== 'undefined' ? __INITIAL_STATE__ : { i18n: { locale: 'en-GB', messages: {} } };
#   </script>
#   <!-- START-FRAGMENT dashboard-spa-container.html -->
#   <!-- 0.0.15-2965 -->
#   <div class="confluence-dashboard" id="confluence-ui">
#    <div>
#     <div>
#      <div style="display: flex;">
#       <div class="ConfluenceNavigation_container_38S" id="confluenceNavigation">
#        <div class="CommonPageNavigation_alwaysOnTop_3EI nps-dialog-target" data-sidebar-collapsed="false" id="confluence-left-nav">
#         <div>
#          <div class="iesXqK" style="width: 360px;">
#           <div class="dRGBZY">
#            <div class="fNYoNv">
#             <div class="kVYZSO">
#              <div class="fpjBFW">
#               <div class="bmpwdQ">
#                <div class="kGUpjB">
#                 <div appearance="round" class="kLDOyn">
#                  <span class="confluence-nav-primary-icon-link" id="logo">
#                   <style>
#                    .confluence-nav-primary-icon-link a { color: inherit !important; }
#                   </style>
#                   <style>
#                    .confluence-nav-primary-icon-link a div{ display: flex }
#                   </style>
#                   <a aria-current="true" class="active" href="/wiki">
#                    <div>
#                     <span aria-label="Confluence" class="igkRrc">
#                      <svg focusable="false" height="24" role="presentation" viewbox="0 0 24 24" width="24">
#                       <defs>
#                        <lineargradient id="a-75aa203a-8872-4b50-b975-874dec559fc5" x1="99.14%" x2="35.185%" y1="112.745%" y2="39.29%">
#                         <stop offset="0%" stop-color="inherit" stop-opacity=".4">
#                         </stop>
#                         <stop offset="100%" stop-color="inherit">
#                         </stop>
#                        </lineargradient>
#                        <lineargradient id="b-75aa203a-8872-4b50-b975-874dec559fc5" x1="14.184%" x2="60.198%" y1="5.8%" y2="69.657%">
#                         <stop offset="0%" stop-color="inherit" stop-opacity=".4">
#                         </stop>
#                         <stop offset="100%" stop-color="inherit">
#                         </stop>
#                        </lineargradient>
#                       </defs>
#                       <path d="M4.808 16.017c-.163.265-.345.573-.5.818a.5.5 0 0 0 .167.68l3.25 2a.5.5 0 0 0 .693-.17c.13-.217.297-.5.48-.802 1.287-2.125 2.582-1.866 4.917-.75l3.223 1.532a.5.5 0 0 0 .672-.25l1.547-3.5a.5.5 0 0 0-.25-.655c-.68-.32-2.032-.957-3.25-1.545-4.38-2.125-8.102-1.985-10.95 2.642z" fill="url(#a-75aa203a-8872-4b50-b975-874dec559fc5)">
#                       </path>
#                       <path d="M19.38 8.078c.163-.265.345-.573.5-.818a.5.5 0 0 0-.168-.68l-3.25-2a.5.5 0 0 0-.712.17c-.13.218-.297.5-.48.803-1.287 2.125-2.582 1.865-4.918.75L7.14 4.772a.5.5 0 0 0-.672.25l-1.548 3.5a.5.5 0 0 0 .25.655c.68.32 2.032.957 3.25 1.544 4.39 2.123 8.112 1.983 10.96-2.644z" fill="url(#b-75aa203a-8872-4b50-b975-874dec559fc5)">
#                       </path>
#                      </svg>
#                     </span>
#                    </div>
#                   </a>
#                  </span>
#                 </div>
#                </div>
#                <div class="kfFTAe">
#                 <div>
#                  <div>
#                   <div>
#                    <button class="fnfSVQ" type="button">
#                     <div class="global-search-icon">
#                      <span aria-label="Search" class="nHRjF">
#                       <svg focusable="false" height="24" role="presentation" viewbox="0 0 24 24" width="24">
#                        <path d="M16.436 15.085l3.94 4.01a1 1 0 0 1-1.425 1.402l-3.938-4.006a7.5 7.5 0 1 1 1.423-1.406zM10.5 16a5.5 5.5 0 1 0 0-11 5.5 5.5 0 0 0 0 11z" fill="currentColor" fill-rule="evenodd">
#                        </path>
#                       </svg>
#                      </span>
#                     </div>
#                    </button>
#                   </div>
#                  </div>
#                  <div>
#                   <div>
#                    <button class="fnfSVQ" type="button">
#                     <div id="create-page-button">
#                      <span aria-label="Create" class="nHRjF">
#                       <svg focusable="false" height="24" role="presentation" viewbox="0 0 24 24" width="24">
#                        <path d="M13 11V3.993A.997.997 0 0 0 12 3c-.556 0-1 .445-1 .993V11H3.993A.997.997 0 0 0 3 12c0 .557.445 1 .993 1H11v7.007c0 .548.448.993 1 .993.556 0 1-.445 1-.993V13h7.007A.997.997 0 0 0 21 12c0-.556-.445-1-.993-1H13z" fill="currentColor" fill-rule="evenodd">
#                        </path>
#                       </svg>
#                      </span>
#                     </div>
#                    </button>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="dEthyU">
#               <div>
#                <div>
#                 <div>
#                  <div>
#                   <div>
#                    <div style="width: 100%; cursor: pointer;">
#                     <div>
#                      <button class="jFcgpm" type="button">
#                       <div style="position: relative; display: inline-flex;">
#                        <span style="position: absolute; right: 0px; top: 0px; background: rgb(255, 86, 48) none repeat scroll 0% 0%; border-radius: 50%; width: 7px; height: 7px;">
#                        </span>
#                        <span aria-label="Notifications" class="nHRjF">
#                         <svg focusable="false" height="24" role="presentation" viewbox="0 0 24 24" width="24">
#                          <path d="M6.485 17.669a2 2 0 0 0 2.829 0l-2.829-2.83a2 2 0 0 0 0 2.83zm4.897-12.191l-.725.725c-.782.782-2.21 1.813-3.206 2.311l-3.017 1.509c-.495.248-.584.774-.187 1.171l8.556 8.556c.398.396.922.313 1.171-.188l1.51-3.016c.494-.988 1.526-2.42 2.311-3.206l.725-.726a5.048 5.048 0 0 0 .64-6.356 1.01 1.01 0 1 0-1.354-1.494c-.023.025-.046.049-.066.075a5.043 5.043 0 0 0-2.788-.84 5.036 5.036 0 0 0-3.57 1.478z" fill="currentColor" fill-rule="evenodd">
#                          </path>
#                         </svg>
#                        </span>
#                       </div>
#                      </button>
#                     </div>
#                    </div>
#                   </div>
#                   <div class="eftsfW">
#                    <div style="top: 0px; left: 0px; position: fixed; z-index: 400; transform: translate3d(54px, 644px, 0px);">
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div>
#                 <div class="AppSwitcher_root_2lO">
#                  <span class="huJKFU">
#                   <div>
#                    <div class="jFqSsi">
#                     <div>
#                      <div>
#                       <div class="dGPJeK">
#                        <div>
#                         <button class="jFcgpm" type="button">
#                          <span aria-label="Application Switcher" class="nHRjF">
#                           <svg focusable="false" height="24" role="presentation" viewbox="0 0 24 24" width="24">
#                            <path d="M5 15h14v2H5zm0-8h14v2H5zm0 4h14v2H5z" fill="currentColor" fill-rule="evenodd">
#                            </path>
#                           </svg>
#                          </span>
#                         </button>
#                        </div>
#                       </div>
#                      </div>
#                      <div class="eftsfW">
#                       <div style="top: 0px; left: 0px; position: absolute; z-index: 400; opacity: 0;">
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </span>
#                 </div>
#                </div>
#                <div>
#                 <div class="WebItemDropdownMenu_root_Rr2" data-content-id="187301909" data-webitem-location="system.help/pages">
#                  <div>
#                   <div class="jFqSsi">
#                    <div>
#                     <div>
#                      <div class="dGPJeK">
#                       <div>
#                        <div class="" id="help-menu-link">
#                         <div>
#                          <button class="jFcgpm" type="button">
#                           <span aria-label="Help" class="gIaLUt">
#                            <svg focusable="false" height="24" role="presentation" viewbox="0 0 24 24" width="24">
#                             <g fill-rule="evenodd">
#                              <circle cx="12" cy="12" fill="currentColor" r="10">
#                              </circle>
#                              <circle cx="12" cy="18" fill="inherit" r="1">
#                              </circle>
#                              <path d="M15.89 9.05a3.975 3.975 0 0 0-2.957-2.942C10.321 5.514 8.017 7.446 8 9.95l.005.147a.992.992 0 0 0 .982.904c.552 0 1-.447 1.002-.998a2.004 2.004 0 0 1 4.007-.002c0 1.102-.898 2-2.003 2H12a1 1 0 0 0-1 .987v2.014a1.001 1.001 0 0 0 2.004 0v-.782c0-.217.145-.399.35-.472A3.99 3.99 0 0 0 15.89 9.05" fill="inherit">
#                              </path>
#                             </g>
#                            </svg>
#                           </span>
#                          </button>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                     <div class="eftsfW">
#                      <div style="top: 0px; left: 0px; position: absolute; z-index: 400; opacity: 0;">
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div>
#                 <div class="WebItemDropdownMenu_root_Rr2" data-content-id="187301909" data-webitem-location="system.user">
#                  <div>
#                   <div class="jFqSsi">
#                    <div>
#                     <div>
#                      <div class="dGPJeK">
#                       <div>
#                        <div>
#                         <button class="jFcgpm" type="button">
#                          <div style="display: inline-block; position: relative; outline: 0px none currentcolor; width: 28px; height: 28px;">
#                           <span class="cgKQFs">
#                            <span role="img" style='background-image: url("/wiki/aa-avatar/cc2a636948176d2ca895bee12b6bb897?s=48&amp;d=https%3A%2F%2Fvcdi-dpc.atlassian.net%2Fwiki%2Fdownload%2Fattachments%2F13697030%2Fuser-avatar%3FnoRedirect%3Dtrue"); background-position: center center; background-repeat: no-repeat; background-size: cover; border-radius: 50%; display: flex; flex: 1 1 100%; height: 100%; width: 100%; background-color: transparent;'>
#                            </span>
#                           </span>
#                          </div>
#                         </button>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                     <div class="eftsfW">
#                      <div style="top: 0px; left: 0px; position: absolute; z-index: 400; opacity: 0;">
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="ggkhUd">
#             <div class="iYJWvo">
#              <div class="hkKnxk">
#              </div>
#              <div class="iClwZr">
#               <div>
#                <div>
#                 <div class="bjlauo">
#                  <div>
#                   <div>
#                    <div class="FCRyk">
#                     <div>
#                      <span aria-disabled="false" class="iNDnTO" tabindex="0">
#                       <span class="dcdzKd">
#                        <div class="bOUELZ">
#                         <div class="wtrXs">
#                          <div style="display: inline-block; position: relative; outline: 0px none currentcolor; width: 36px; height: 36px;">
#                           <span class="dNLcNw">
#                            <span role="img" style='background-image: url("/wiki/images/logo/default-space-logo-256.png"); background-position: center center; background-repeat: no-repeat; background-size: cover; border-radius: 3px; display: flex; flex: 1 1 100%; height: 100%; width: 100%; background-color: transparent;'>
#                            </span>
#                           </span>
#                          </div>
#                         </div>
#                        </div>
#                       </span>
#                       <span class="hAotrp">
#                        <span class="cZezoY">
#                         <span class="bgdPDV">
#                          Analytics Home Page
#                         </span>
#                        </span>
#                       </span>
#                       <span class="beTBpz">
#                        <div class="eMVHAg">
#                         <div class="bOUELZ">
#                          <span aria-label="chevron" class="nHRjF">
#                           <svg focusable="false" height="24" role="presentation" viewbox="0 0 24 24" width="24">
#                            <path d="M8.292 10.293a1.009 1.009 0 0 0 0 1.419l2.939 2.965c.218.215.5.322.779.322s.556-.107.769-.322l2.93-2.955a1.01 1.01 0 0 0 0-1.419.987.987 0 0 0-1.406 0l-2.298 2.317-2.307-2.327a.99.99 0 0 0-1.406 0z" fill="currentColor" fill-rule="evenodd">
#                            </path>
#                           </svg>
#                          </span>
#                         </div>
#                        </div>
#                       </span>
#                      </span>
#                     </div>
#                    </div>
#                   </div>
#                   <div class="eftsfW">
#                    <div style="top: 0px; left: 0px; position: absolute; z-index: 400; opacity: 0;">
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="SpaceNavigationHeader_backButtonContainer_2xT">
#                 <div aria-label="" role="group">
#                  <div data-internal-id="back-button">
#                   <a aria-current="false" class="BackButton_link_1W7" href="/wiki/spaces/AKB/pages">
#                    <span aria-disabled="false" class="fthfuC" tabindex="0">
#                     <span class="dQZXZn">
#                      <div class="bOUELZ">
#                       <span class="BackButton_backIconWrapper_2_P">
#                        <span aria-label="Pages" class="zAaFo">
#                         <svg focusable="false" height="24" role="presentation" viewbox="0 0 24 24" width="24">
#                          <path d="M8.414 11.5H18a1 1 0 0 1 0 2H8.414l3.793 3.793a1 1 0 0 1-1.414 1.414l-5.5-5.5a1 1 0 0 1 0-1.414l5.5-5.5a1 1 0 0 1 1.414 1.414L8.414 11.5z" fill="currentColor" fill-rule="evenodd">
#                          </path>
#                         </svg>
#                        </span>
#                       </span>
#                      </div>
#                     </span>
#                     <span class="hAotrp">
#                      <span class="cZezoY">
#                       Pages
#                      </span>
#                     </span>
#                    </span>
#                   </a>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="bJlPmq">
#               <div class="hPPsOH">
#                <div style="flex-direction: column; flex-grow: 1;">
#                 <div style="display: table; min-width: 100%;">
#                  <ul class="PageTree_node_30k PageTree_root_2FU">
#                   <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-17793079">
#                    <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/17793079/Analytics+Projects">
#                     Analytics Projects
#                    </a>
#                   </li>
#                   <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-188514684">
#                    <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/188514684/Analytics+Team+Members">
#                     Analytics Team Members
#                    </a>
#                   </li>
#                   <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-189366318">
#                    <div class="PageTree_icon_1Dx">
#                     <span aria-label="" class="zAaFo">
#                      <svg focusable="false" height="24" role="presentation" viewbox="0 0 24 24" width="24">
#                       <path d="M8.292 10.293a1.009 1.009 0 0 0 0 1.419l2.939 2.965c.218.215.5.322.779.322s.556-.107.769-.322l2.93-2.955a1.01 1.01 0 0 0 0-1.419.987.987 0 0 0-1.406 0l-2.298 2.317-2.307-2.327a.99.99 0 0 0-1.406 0z" fill="currentColor" fill-rule="evenodd">
#                       </path>
#                      </svg>
#                     </span>
#                    </div>
#                    <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/189366318/Analytics+Project+Management">
#                     Analytics Project Management
#                    </a>
#                    <ul class="PageTree_node_30k">
#                     <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-181174280">
#                      <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/181174280/Analytics+Managers+-+To+Do+List">
#                       Analytics Managers - To Do List
#                      </a>
#                     </li>
#                     <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-55738372">
#                      <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/55738372/Analytics+project+lifecycle">
#                       Analytics project lifecycle
#                      </a>
#                     </li>
#                     <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-17825900">
#                      <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/17825900/Analytics+project+roadmap">
#                       Analytics project roadmap
#                      </a>
#                     </li>
#                     <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-187433013">
#                      <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/187433013/Analytics+Projects+-+Risks+and+Issues">
#                       Analytics Projects - Risks and Issues
#                      </a>
#                     </li>
#                     <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-180912135">
#                      <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/180912135/Filter+Questions+for+new+projects">
#                       Filter Questions for new projects
#                      </a>
#                     </li>
#                     <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-15958200">
#                      <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/15958200/Iterative+Development">
#                       Iterative Development
#                      </a>
#                     </li>
#                     <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-55705622">
#                      <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/55705622/Leads+and+projects+trello+board">
#                       Leads and projects trello board
#                      </a>
#                     </li>
#                     <li class="PageTree_item_d3K PageTree_small_Kte PageTree_selectedItem_30M" data-internal-id="item-187301909">
#                      <a class="PageTree_anchor_20K PageTree_selectedAnchor_Ys_" href="/wiki/spaces/AKB/pages/187301909/Project+Canvas+Template">
#                       Project Canvas Template
#                      </a>
#                     </li>
#                     <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-17334478">
#                      <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/17334478/User+Stories">
#                       User Stories
#                      </a>
#                     </li>
#                    </ul>
#                   </li>
#                   <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-189857861">
#                    <div class="PageTree_icon_1Dx">
#                     <span aria-label="" class="zAaFo">
#                      <svg focusable="false" height="24" role="presentation" viewbox="0 0 24 24" width="24">
#                       <path d="M10.294 9.698a.988.988 0 0 1 0-1.407 1.01 1.01 0 0 1 1.419 0l2.965 2.94a1.09 1.09 0 0 1 0 1.548l-2.955 2.93a1.01 1.01 0 0 1-1.42 0 .988.988 0 0 1 0-1.407l2.318-2.297-2.327-2.307z" fill="currentColor" fill-rule="evenodd">
#                       </path>
#                      </svg>
#                     </span>
#                    </div>
#                    <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/189857861/Knowledge+Base">
#                     Knowledge Base
#                    </a>
#                   </li>
#                   <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-64782337">
#                    <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/64782337/Crash+Analytics">
#                     Crash Analytics
#                    </a>
#                   </li>
#                   <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-167772654">
#                    <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/167772654/Early+Intervention+System">
#                     Early Intervention System
#                    </a>
#                   </li>
#                   <li class="PageTree_item_d3K PageTree_small_Kte" data-internal-id="item-97550337">
#                    <a class="PageTree_anchor_20K" href="/wiki/spaces/AKB/pages/97550337/Test+datasets">
#                     Test datasets
#                    </a>
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="dEthyU">
#               <div class="hkKnxk">
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="hfwnul">
#             <button aria-expanded="true" class="gsOGuN">
#             </button>
#            </div>
#           </div>
#          </div>
#          <div>
#           <div class="bQgyAv">
#           </div>
#          </div>
#          <div>
#           <div class="bQgyAv">
#           </div>
#          </div>
#          <div>
#           <div class="bQgyAv">
#           </div>
#          </div>
#         </div>
#         <div style="position: fixed; z-index: 1;">
#         </div>
#         <div>
#         </div>
#         <div data-content-id="187301909" data-webitem-location="system.header/left.button.group">
#         </div>
#        </div>
#        <div>
#         <style>
#          /* Applies to global "ADG3" font families. */
#                     body, body.aui-layout { font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", "Roboto", "Noto Sans", "Ubuntu", "Droid Sans", "Helvetica Neue", sans-serif; }
#
#                     /* Resets the background colors to white (which were previously set to gray by AUI */
#                     body { background-color:transparent; }
#                     div#full-height-container { background-color:transparent; }
#
#                     body .aui-page-panel { border:none; position:inherit; margin:0; }
#
#                     /* Make the header transparent on legacy pages that contain the ADG3 sidebar. */
#                     body #main-header { background-color:transparent !important; }
#
#                     /* Make the secondary navigation on legacy pages look slightly nicer. This should be replaced with an AtlasKit component eventually. */
#                     body .aui-navgroup-horizontal { background-color: transparent; margin:0 0 24px 0; border-top:none; }
#                     body .aui-navgroup-horizontal .aui-nav a { color: #333; }
#                     body .aui-navgroup-horizontal .aui-nav a:hover { background-color:transparent; text-decoration:underline; }
#                     body .aui-navgroup-horizontal .aui-nav > .aui-nav-selected a { border-bottom:3px solid #205081; }
#                     body .aui-navgroup-horizontal .aui-nav > .aui-nav-selected a:before,
#                     body .aui-navgroup-horizontal .aui-nav > .aui-nav-selected a:after { border:none; }
#         </style>
#        </div>
#       </div>
#       <div class="MainStage_mainStageContainer_1TS" style="width: 100%; min-width: 700px; flex-flow: row wrap;">
#        <div class="MainStage_webPanelWrapper_2jF">
#        </div>
#        <div class="MainStage_AUIPageContent_ygU">
#         <div class="MainStage_contentBody_1HS" id="content-body" style="padding: 0px; width: 100%;">
#          <div>
#           <div class="wrapper-space-view-page" style="">
#            <div>
#             <div>
#              <div>
#               <div>
#                <div id="likes-section">
#                </div>
#               </div>
#              </div>
#              <div style="position: relative; padding: 0px 20px 20px 30px; min-height: 100vh; box-sizing: border-box;">
#               <div style="display: block; position: absolute; width: 100%; top: 0px; left: 0px; height: 375px; background-color: rgb(219, 219, 219);">
#               </div>
#               <div class="content-screen-wrapper" style="position: relative;">
#                <div style="overflow: hidden;">
#                </div>
#                <div style="background-color: rgb(255, 255, 255); background-image: none; background-size: auto auto; padding: 20px; border-radius: 0px; margin: 50px 5%; width: 90%; box-sizing: border-box;">
#                 <header class="ViewPageHeaderComponent_header_1yn " style="min-height: 52px;">
#                  <div class="ViewPageHeaderComponent_content_3aY">
#                   <div class="ViewPageHeaderComponent_breadcrumbs_2Gv">
#                    <div class="boOJAH">
#                     <div class="hwwRsq">
#                      <a class="ihyVSq eBgdfa" href="/wiki/spaces/AKB/overview" spacing="none" target="">
#                       <span style="align-self: center; display: inline-flex; flex-wrap: nowrap; max-width: 100%; position: relative;">
#                        <span style="align-items: center; align-self: center; flex: 1 1 auto; margin: 0px; max-width: 100%; overflow: hidden; text-overflow: ellipsis; white-space: nowrap; transition: opacity 0.3s ease 0s; opacity: 1;">
#                         Analytics Home Page
#                        </span>
#                       </span>
#                      </a>
#                      <div class="dPDwxe">
#                       /
#                      </div>
#                     </div>
#                     <div class="hwwRsq">
#                      <a class="ihyVSq eBgdfa" href="/wiki/spaces/AKB/pages" spacing="none" target="">
#                       <span style="align-self: center; display: inline-flex; flex-wrap: nowrap; max-width: 100%; position: relative;">
#                        <span style="align-items: center; align-self: center; flex: 1 1 auto; margin: 0px; max-width: 100%; overflow: hidden; text-overflow: ellipsis; white-space: nowrap; transition: opacity 0.3s ease 0s; opacity: 1;">
#                         Pages
#                        </span>
#                       </span>
#                      </a>
#                      <div class="dPDwxe">
#                       /
#                      </div>
#                     </div>
#                     <div class="hwwRsq">
#                      <a class="ihyVSq eBgdfa" href="/wiki/spaces/AKB/pages/189366318/Analytics+Project+Management" spacing="none" target="">
#                       <span style="align-self: center; display: inline-flex; flex-wrap: nowrap; max-width: 100%; position: relative;">
#                        <span style="align-items: center; align-self: center; flex: 1 1 auto; margin: 0px; max-width: 100%; overflow: hidden; text-overflow: ellipsis; white-space: nowrap; transition: opacity 0.3s ease 0s; opacity: 1;">
#                         Analytics Project Management
#                        </span>
#                       </span>
#                      </a>
#                     </div>
#                    </div>
#                    <span data-content-id="187301909" data-webitem-location="system.content.metadata">
#                     <div class="WebItemButtonList_metadataButtons_1iF" id="system-content-items">
#                      <a class="aui-icon aui-icon-small aui-iconfont-unlocked system-metadata-restrictions" href="" id="content-metadata-page-restrictions" resolved="" title="Unrestricted">
#                       <span>
#                        restrictions.none
#                       </span>
#                      </a>
#                     </div>
#                    </span>
#                    <span data-content-id="187301909" data-webitem-location="page.metadata.banner">
#                     <div class="WebItemButtonList_metadataButtons_1iF" id="page-metadata-banner-items">
#                      <a class="aui-button aui-button-subtle content-metadata-jira tipsy-disabled hidden" data-jira-metadata-count="-1" href="" id="content-metadata-jira" resolved="">
#                       <span>
#                        Jira links
#                       </span>
#                      </a>
#                     </div>
#                    </span>
#                   </div>
#                   <div class="ViewPageHeaderComponent_navigationContainer_15E content-navigation view" style="min-height: 31px;">
#                    <span data-content-id="187301909" data-webitem-location="system.content.button">
#                     <div class="aui-buttons WebItemButtonList_pageButtons_3i-">
#                      <a class="edit full-load aui-button-subtle aui-button" href="/wiki/pages/editpage.action?pageId=187301909" id="editPageLink" title="Edit">
#                       <span class="aui-icon aui-icon-small aui-iconfont-edit" style="color: rgb(119, 119, 119);">
#                       </span>
#                       <span>
#                        <u>
#                         E
#                        </u>
#                        dit
#                       </span>
#                      </a>
#                      <a class="action-page-favourite aui-button-subtle aui-button" href="/wiki" id="page-favourite" resolved="" title="Save for later">
#                       <span class="aui-icon aui-icon-small aui-iconfont-unstar" style="color: rgb(119, 119, 119);">
#                       </span>
#                       <span>
#                        Save
#                        <u>
#                         f
#                        </u>
#                        or later
#                       </span>
#                      </a>
#                      <a class="watch-menu watch-content-button aui-button-subtle aui-button watch-state-initialised" href="/wiki" id="watch-content-button" resolved="" title="Stop watching (w)">
#                       <span>
#                        <span class="aui-icon aui-icon-small aui-iconfont-watch" style="color: rgb(119, 119, 119);">
#                         <span class="aui-icon aui-icon-small aui-iconfont-watch" style="color: rgb(119, 119, 119);">
#                         </span>
#                         <u>
#                          W
#                         </u>
#                         atching
#                        </span>
#                        <u>
#                         W
#                        </u>
#                        atching
#                       </span>
#                      </a>
#                      <a class="share webitem-invite-button aui-button-subtle aui-button" href="/wiki" id="inviteToEdit" resolved="" title="Share this page with others">
#                       <span class="aui-icon aui-icon-small aui-iconfont-share" style="color: rgb(119, 119, 119);">
#                       </span>
#                       <span>
#                        <u>
#                         S
#                        </u>
#                        hare
#                       </span>
#                      </a>
#                     </div>
#                    </span>
#                    <span data-content-id="187301909" data-webitem-location="system.content.action">
#                     <div class="ToolsMenu_root_1pt">
#                      <div aria-controls="dropddown-1526452952416" aria-expanded="false" aria-haspopup="true" class="ToolsMenu_dots_1GZ aui-dropdown2-trigger aui-dropdown2-trigger-arrowless aui-button aui-button-subtle" id="action-menu-link" resolved="">
#                       <span class="aui-icon aui-icon-small aui-iconfont-more">
#                       </span>
#                      </div>
#                      <div aria-hidden="true" class="aui-dropdown2 aui-style-default aui-layer" id="dropddown-1526452952416" resolved="">
#                       <div>
#                        <div class="aui-dropdown2-section">
#                         <ul class="section-leading" id="action-menu-leading">
#                          <li>
#                           <a class="" href="/wiki/plugins/servlet/ac/com.comalatech.cloud.approvals/cwc-approval-history?page.id=187301909&amp;user.key=8a7f80836102c270016106366c910151&amp;space.key=AKB&amp;content.id=187301909&amp;user.id=daniel.corcoran&amp;content.version=11&amp;page.type=page&amp;page.title=Project%20Canvas%20Template&amp;space.id=16285844&amp;content.type=page&amp;page.version=11" id="com.comalatech.cloud.approvals__cwc-history">
#                            <span>
#                             Workflow History
#                            </span>
#                           </a>
#                          </li>
#                         </ul>
#                        </div>
#                        <div class="aui-dropdown2-section">
#                         <ul class="section-primary" id="action-menu-primary">
#                          <li>
#                           <a class="action-view-attachments" href="/wiki/pages/viewpageattachments.action?pageId=187301909" id="view-attachments-link" title="View Attachments">
#                            <span>
#                             A
#                             <u>
#                              t
#                             </u>
#                             tachments (0)
#                            </span>
#                           </a>
#                          </li>
#                          <li>
#                           <a class="action-view-history" href="/wiki/pages/viewpreviousversions.action?pageId=187301909" id="action-view-history-link">
#                            <span>
#                             Page History
#                            </span>
#                           </a>
#                          </li>
#                          <li>
#                           <a class="action-page-permissions" href="/wiki/pages/viewinfo.action?pageId=187301909" id="action-page-permissions-link" resolved="" title="Edit restrictions">
#                            <span>
#                             Restrictions
#                            </span>
#                           </a>
#                          </li>
#                         </ul>
#                        </div>
#                        <div class="aui-dropdown2-section">
#                         <ul class="section-secondary" id="action-menu-secondary">
#                          <li>
#                           <a class="action-view-info" href="/wiki/pages/viewinfo.action?pageId=187301909" id="view-page-info-link">
#                            <span>
#                             Page Information
#                            </span>
#                           </a>
#                          </li>
#                          <li>
#                           <a class="" href="/wiki" id="view-resolved-comments">
#                            <span>
#                             Resolved comments (0)
#                            </span>
#                           </a>
#                          </li>
#                          <li>
#                           <a class="action-link-page" href="/wiki/pages/viewinfo.action?pageId=187301909" id="link-to-page-link" resolved="" title="Link to this Page">
#                            <span>
#                             Link to this Page…
#                            </span>
#                           </a>
#                          </li>
#                          <li>
#                           <a class="" href="/wiki/pages/listpages-dirview.action?key=AKB&amp;openId=187301909#selectedPageInHierarchy" id="view-in-hierarchy-link">
#                            <span>
#                             View in Hierarchy
#                            </span>
#                           </a>
#                          </li>
#                          <li>
#                           <a class="action-view-source popup-link" href="/wiki/plugins/viewsource/viewpagesrc.action?pageId=187301909" id="action-view-source-link">
#                            <span>
#                             View Source
#                            </span>
#                           </a>
#                          </li>
#                          <li>
#                           <a class="" href="/wiki/spaces/flyingpdf/pdfpageexport.action?pageId=187301909" id="action-export-pdf-link">
#                            <span>
#                             Export to PDF
#                            </span>
#                           </a>
#                          </li>
#                          <li>
#                           <a class="action-export-word" href="/wiki/exportword?pageId=187301909" id="action-export-word-link">
#                            <span>
#                             Export to Word
#                            </span>
#                           </a>
#                          </li>
#                          <li>
#                           <a class="" href="/wiki/pages/wordimport/wordimportupload.action?pageId=187301909" id="import-word-doc">
#                            <span>
#                             Import Word Document
#                            </span>
#                           </a>
#                          </li>
#                         </ul>
#                        </div>
#                        <div class="aui-dropdown2-section">
#                         <ul class="section-modify" id="action-menu-modify">
#                          <li>
#                           <a class="action-copy" href="/wiki/pages/copypage.action?idOfPageToCopy=187301909&amp;spaceKey=AKB" id="action-copy-page-link">
#                            <span>
#                             Copy
#                            </span>
#                           </a>
#                          </li>
#                          <li>
#                           <a class="action-move" href="/wiki/pages/viewpage.action?pageId=187301909" id="action-move-page-dialog-link">
#                            <span>
#                             Move
#                            </span>
#                           </a>
#                          </li>
#                         </ul>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </span>
#                   </div>
#                  </div>
#                  <div class="ViewPageHeaderComponent_stickyBorder_1wn">
#                  </div>
#                 </header>
#                 <div style="display: inline-block; box-sizing: border-box; width: 100%; background-color: rgb(255, 255, 255); background-image: none; background-size: auto auto; padding: 30px 30px 10px; border-radius: 3px 3px 0px 0px;">
#                  <div class="" data-internal-id="page-content-header">
#                   <h1 class="ViewPage_title_3-I" data-internal-id="title-text" id="title-text">
#                    Project Canvas Template
#                   </h1>
#                   <div class="page-metadata-modification-info ByLineComponent_root_sWA">
#                    <div class="ByLineComponent_avatarWrapper_2YL">
#                     <a href="/wiki/display/~sweta.patel">
#                      <img alt="User icon" src="/wiki/aa-avatar/86737cb56d2cb00df0e256b57325cb09?s=48&amp;d=https%3A%2F%2Fvcdi-dpc.atlassian.net%2Fwiki%2Fimages%2Ficons%2Fprofilepics%2Fdefault.png%3FnoRedirect%3Dtrue" style="border-radius: 50%; width: 32px; height: 32px;"/>
#                     </a>
#                    </div>
#                    <div class="ByLineComponent_textContainer_P1v">
#                     <div class="ByLineComponent_author_2IC">
#                      <div style="display: inline-block;">
#                       <div>
#                        <a class="confluence-userlink" data-user-hover-bound="true" data-username="sweta.patel" href="/wiki/display/~sweta.patel">
#                         Sweta Patel
#                        </a>
#                       </div>
#                      </div>
#                     </div>
#                     <span class="last-modified ByLineComponent_lastModified_1z6">
#                      <span>
#                       Last modified
#                       <a href="/wiki/pages/diffpagesbyversion.action?pageId=187301909&amp;selectedPageVersions=10&amp;selectedPageVersions=11">
#                        3 minutes ago
#                       </a>
#                      </span>
#                     </span>
#                     <span data-content-id="187301909" data-webitem-location="system.content.byline">
#                      <span class="ByLineWebItems_webItemsList_2a4">
#                       <a class="ap-inline-dialog ap-plugin-key-com.comalatech.cloud.approvals ap-module-key-cwc-workflow-byline ByLineWebItems_bylineWebItem_2kP" href="/wiki/plugins/servlet/ac/com.comalatech.cloud.approvals//workflow/overview/{space.key}/{content.id}?contentVersion={content.version}&amp;darkDebug={condition.feature_flag(featureKey=cwc.debug)}&amp;darkWorkflows={condition.feature_flag(featureKey=cwc.workflows)}&amp;page.id=187301909&amp;user.key=8a7f80836102c270016106366c910151&amp;space.key=AKB&amp;content.id=187301909&amp;user.id=daniel.corcoran&amp;content.version=11&amp;page.type=page&amp;page.title=Project%20Canvas%20Template&amp;space.id=16285844&amp;content.type=page&amp;page.version=11" id="com.comalatech.cloud.approvals__cwc-workflow-byline" resolved="" title="Approval Status">
#                        <img alt="Review" src="https://comalatech-cwc-production.herokuapp.com/images/byl-review.svg" title="Review"/>
#                        <span>
#                         Review
#                        </span>
#                       </a>
#                      </span>
#                     </span>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                 <div style="background-color: rgb(255, 255, 255); background-image: none; background-size: auto auto; padding: 0px 30px 30px; border-radius: 0px 0px 3px 3px;">
#                  <div class="" data-internal-id="page-content-only">
#                   <div class="page view" id="content">
#                    <div>
#                     <link data-wrm-batch-type="resource" data-wrm-key="com.atlassian.confluence.plugins.confluence-inline-tasks:inline-tasks-styles" href="//d245y5s2hyv7y6.cloudfront.net/vcdi-dpc.atlassian.net/wiki/s/d41d8cd98f00b204e9800998ecf8427e-CDN/-100165870/h/4fdbbeaf5670b4f3439d84e78097e3a2/_/download/batch/com.atlassian.confluence.plugins.confluence-inline-tasks:inline-tasks-styles/com.atlassian.confluence.plugins.confluence-inline-tasks:inline-tasks-styles.css?externals=__local-default__&amp;relative-url=true" media="all" rel="stylesheet" type="text/css"/>
#                     <link data-wrm-batch-type="resource" data-wrm-key="com.atlassian.confluence.plugins.confluence-ui-components:blank-placeholder-box" href="//d245y5s2hyv7y6.cloudfront.net/vcdi-dpc.atlassian.net/wiki/s/d41d8cd98f00b204e9800998ecf8427e-CDN/-100165870/h/1e7bf89a04b307f389d280ea8fef8d53/_/download/batch/com.atlassian.confluence.plugins.confluence-ui-components:blank-placeholder-box/com.atlassian.confluence.plugins.confluence-ui-components:blank-placeholder-box.css?externals=__local-default__&amp;relative-url=true" media="all" rel="stylesheet" type="text/css"/>
#                     <link data-wrm-batch-type="resource" data-wrm-key="com.atlassian.confluence.plugins.confluence-inline-tasks:sortable-table-styles" href="//d245y5s2hyv7y6.cloudfront.net/vcdi-dpc.atlassian.net/wiki/s/d41d8cd98f00b204e9800998ecf8427e-CDN/-100165870/h/b46e3b033892d2329c6ddc888a3066d1/_/download/batch/com.atlassian.confluence.plugins.confluence-inline-tasks:sortable-table-styles/com.atlassian.confluence.plugins.confluence-inline-tasks:sortable-table-styles.css?externals=__local-default__&amp;relative-url=true" media="all" rel="stylesheet" type="text/css"/>
#                     <link data-wrm-batch-type="resource" data-wrm-key="com.atlassian.confluence.plugins.confluence-inline-tasks:tasks-report-resources" href="//d245y5s2hyv7y6.cloudfront.net/vcdi-dpc.atlassian.net/wiki/s/d41d8cd98f00b204e9800998ecf8427e-CDN/-100165870/h/e263d3663240c6f4768f969aea54f1c4/_/download/batch/com.atlassian.confluence.plugins.confluence-inline-tasks:tasks-report-resources/com.atlassian.confluence.plugins.confluence-inline-tasks:tasks-report-resources.css?externals=__local-default__&amp;relative-url=true" media="all" rel="stylesheet" type="text/css"/>
#                     <link href="//d245y5s2hyv7y6.cloudfront.net/vcdi-dpc.atlassian.net/wiki/s/-1110209924/6452/b38cca441ee5573ab52d0765fb8d749e9216efaf/4/_/styles/colors.css" media="all" rel="stylesheet" type="text/css"/>
#                    </div>
#                    <div class="wiki-content" id="main-content">
#                     <p>
#                      <br/>
#                     </p>
#                     <div class="table-wrap">
#                      <table class="relative-table wrapped confluenceTable" resolved="" style="width: 97.1476%;">
#                       <colgroup>
#                        <col style="width: 2.88136%;"/>
#                        <col style="width: 0.79096%;"/>
#                        <col style="width: 18.3051%;"/>
#                        <col style="width: 0.112994%;"/>
#                        <col style="width: 2.48588%;"/>
#                        <col style="width: 8.53107%;"/>
#                        <col style="width: 24.5763%;"/>
#                        <col style="width: 20.5085%;"/>
#                        <col style="width: 0.112994%;"/>
# ...
#          Keyboard shortcuts help
#         </span>
#        </a>
#       </li>
#      </ul>
#     </div>
#     <ul class="synchrony-doc-187301909 collaborative-avatars-list" id="avatar-list">
#      <li class="avatar-item p9 active no-animate-entry show">
#       <span avatar="D" class="avatar active" data-origin="current-user" original-title="Look at you, getting stuff done!">
#        <img src="/wiki/aa-avatar/cc2a636948176d2ca895bee12b6bb897?s=48&amp;d=https%3A%2F%2Fvcdi-dpc.atlassian.net%2Fwiki%2Fdownload%2Fattachments%2F13697030%2Fuser-avatar%3FnoRedirect%3Dtrue"/>
#       </span>
#      </li>
#     </ul>
#     <aui-inline-dialog alignment="bottom right" aria-hidden="true" class="aui-layer" id="more-avatars" resolved="" responds-to="toggle">
#      <div class="aui-inline-dialog-contents">
#       <h3>
#        More editors
#       </h3>
#       <ul class="collaborative-avatars-list" id="more-avatars-list">
#       </ul>
#      </div>
#     </aui-inline-dialog>
#     <span class="overlay avatar" id="synchrony-presence-overlay">
#      <a aria-controls="more-avatars" aria-expanded="false" aria-haspopup="true" class="aui-button" data-aui-trigger="" href="#" original-title="" resolved="">
#      </a>
#     </span>
#    </div>
#   </div>
#   <div id="editor-notifications-container">
#    <div id="all-messages">
#     <div id="action-messages">
#     </div>
#    </div>
#   </div>
#   <div id="editor-precursor">
#    <div class="cell">
#     <div class="aui-buttons aui-toolbar2">
#      <button class="aui-button aui-button-subtle rte-button-labels" data-explicit-restrictions="" data-inherited-restrictions="" data-tooltip="Labels" id="rte-button-labels" type="button">
#       <span class="icon aui-icon aui-icon-small aui-iconfont-devtools-tag">
#       </span>
#      </button>
#      <button class="aui-button aui-button-subtle rte-button-restrictions" data-explicit-restrictions="false" data-inherited-restrictions="false" data-tooltip="Unrestricted" id="rte-button-restrictions" resolved="" type="button">
#       <span class="icon aui-icon aui-icon-small aui-iconfont-unlocked">
#       </span>
#      </button>
#     </div>
#     <div data-collaborative-render="true" id="content-title-div">
#      <input autocomplete="off" class="text pagetitle" id="content-title" name="title" placeholder="Page title" tabindex="1" type="text" value="Project Canvas Template"/>
#     </div>
#    </div>
#   </div>
#   <div id="wysiwyg">
#    <div class="cell editor-default" data-collaborative-render="!false" id="rte">
#     <textarea class="hidden tinymce-editor" id="wysiwygTextarea" name="wysiwygContent"></textarea>
#    </div>
#   </div>
#   <div class="hidden" id="editor-html-source-container">
#    <textarea class="monospaceInput" id="editor-html-source"></textarea>
#   </div>
#   <div id="preview">
#    <div class="cell" id="previewArea">
#    </div>
#   </div>
#   <div id="savebar-container">
#    <div class="aui-toolbar aui-toolbar2" id="rte-savebar">
#     <div class="toolbar-split toolbar-split-row">
#      <div class="toolbar-split toolbar-split-left">
#       <div class="aui-buttons">
#       </div>
#      </div>
#      <div class="toolbar-split toolbar-split-right">
#       <div class="aui-buttons" id="rte-savebar-tinymce-plugin-point">
#       </div>
#       <div class="toolbar-item rte-toolbar-pluggable-status" id="pluggable-status-container">
#        <div id="pluggable-status">
#        </div>
#       </div>
#       <div class="aui-buttons">
#        <span class="toolbar-item shared-drafts" id="rte-spinner">
#        </span>
#       </div>
#       <div class="save-button-container">
#        <button class="aui-button aui-button-primary" id="rte-button-publish" name="confirm" title="Save" type="submit" value="Save">
#         <span class="trigger-text">
#          Save
#         </span>
#        </button>
#       </div>
#       <div class="aui-buttons cancel-button-container-shared-draft">
#        <button class="aui-button toolbar-item aui-button-light rte-button-cancel-shared-drafts" id="rte-button-cancel" name="cancel" type="button" value="cancel">
#         Close
#        </button>
#       </div>
#       <div class="aui-buttons toolbar-group-edit assistive">
#        <button class="aui-button aui-button-light" id="rte-button-edit" title="Return to edit mode" type="button">
#         <span class="trigger-text">
#          Edit
#         </span>
#        </button>
#       </div>
#       <div class="aui-buttons toolbar-group-preview">
#        <button aria-controls="rte-ellipsis-menu" aria-expanded="false" aria-haspopup="true" class="aui-button toolbar-item toolbar-item-link aui-button-link aui-dropdown2-trigger aui-dropdown2-trigger-arrowless" id="rte-button-ellipsis" resolved="" type="button">
#         <span class="aui-icon aui-icon-small aui-iconfont-more">
#         </span>
#        </button>
#       </div>
#       <div aria-hidden="true" class="aui-style-default aui-dropdown2 aui-layer" data-aui-alignment="top auto" id="rte-ellipsis-menu" resolved="">
#        <div class="aui-dropdown2-section">
#         <ul class="aui-list-truncate">
#          <li>
#           <a href="#" id="rte-button-preview">
#            Preview
#           </a>
#          </li>
#          <li>
#           <a href="#" id="rte-show-changes">
#            View changes
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="aui-dropdown2-section">
#         <ul class="aui-list-truncate">
#          <li>
#           <a href="#" id="rte-show-revert">
#            Revert to last published version
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <section aria-hidden="true" class="aui-layer aui-dialog2 aui-dialog2-medium" id="quit-editor-dialog" role="dialog">
#    <header class="aui-dialog2-header">
#    </header>
#    <div class="aui-dialog2-content">
#    </div>
#    <footer class="aui-dialog2-footer">
#     <div class="aui-dialog2-footer-actions">
#      <button class="aui-button aui-button-primary update" id="qed-publish-button">
#       Publish
#      </button>
#      <button class="aui-button aui-button-light exit" id="qed-discard-button" title="Discard all unpublished changes">
#       Revert page
#      </button>
#      <button class="aui-button aui-button-primary exit" id="qed-save-exit-button">
#       Keep draft
#      </button>
#      <button class="aui-button aui-button-link" id="qed-close-button">
#       Cancel
#      </button>
#     </div>
#    </footer>
#   </section>
#  </div>
#  <script id="dynamic-editor-metadata-template" title="dynamic-editor-metadata" type="text/x-template">
#   <meta name="ajs-use-watch" content="false">
#             <meta name="ajs-attachment-source-content-id" content="187301909">
#             <meta name="ajs-use-inline-tasks" content="true">
#             <meta name="ajs-heartbeat" content="true">
#             <meta name="ajs-action-locale" content="en_GB">
#             <meta name="ajs-editor-plugin-resource-prefix" content="/wiki/s/-1110209924/6452/b38cca441ee5573ab52d0765fb8d749e9216efaf/_">
#             <meta name="ajs-edit-mode" content="collaborative">
#             <meta name="ajs-user-watching-own-content" content="true">
#             <meta name="ajs-new-page" content="false">
#             <meta name="ajs-editor-mode" content="richtext">
#             <meta name="ajs-auto-start" content="false">
#             <meta name="ajs-conf-revision" content="confluence$content$187301909.52">
#             <meta name="ajs-sync-revision-source" content="synchrony-ack">
#             <meta name="ajs-draft-id" content="187433002">
#             <meta name="ajs-draft-share-id" content="b779af42-0886-4c2b-ba36-f0e36e9bb3b5">
#             <meta name="ajs-content-type" content="page">
#             <meta name="ajs-editor-frontend-enabled" content="true">
#             <meta name="ajs-collaborative-editor-status" content="">
#             <meta name="ajs-content-id" content="187301909">
#             <meta name="ajs-form-name" content="inlinecommentform">
#             <meta name="ajs-can-attach-files" content="true">
#             <meta name="ajs-shared-drafts" content="true">
#             <meta name="ajs-min-editor-height" content="150">
#             <meta name="ajs-version-comment" content="">
#             <meta name="ajs-draft-type" content="page">
#
#                 <meta name="ajs-synchrony-token" content="eyJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjoiUlNBLU9BRVAtMjU2In0.FYxcEZOoQc9sXEGKjHEQg46AbP9OxGN6V4ySYH0EU5shSLNW1pEOTin2NCmRfh3kMAdyVnwWPchvnD3yvMqRPjnRld25ikQVI6kHR7mBiibk25FnXWkrFE0mfeg6-N_lNgUlDt9K8GIfHtJiKjmBQiXyAEwKN1sCMVVb2Y9x3_smrhpm23Sbu_-ebCOrPUxOG0T4_XK1v89MT4feKhcJf9ZlIVtaL4SSmjsQQSuhjujNS99RV30OZt5yPaRvHVjdk09ITsu61pAjBxXh3LxQknoxICYdWsHVlIAa73owF6SNdPL2QP1emB_iAyYfSzXOiANYE45VygLeYqdU995dog8aS9qbRKKrnxZogAQzDiLRyHWclnMB7vbGg3R6xAADgwIOsc6wv4ho2GvaS49TYUuW7v8kyCXkwqxx8Kcv05gwVIzZ69eLYIKs12SA8x_fGS19ABq9FRqLbz7lEuoO6L4kaurJMjU7eul3r_9AU9yBzdV9ypuPDlyhwesi6dca.kMKGMtNujadfzMhN.A9-UWHXWS_73dSzIvqn1dibWdMxESXTaonoGQCvDTmP61KoBZsqzlVj4jKSX1MMvEGqst_EtF9T05hjRK_s7aBKQMvVcKeVsn61Aoo03OUDk0PWF5C7aeSbIqHZNQ9tKO5FjCGyKK4hqu0iI6_QCyfe2SLCNmoLqOGcKdEaXx3aaof2pMTvNt3XuZ9tzfnXGRMkY4q_rECexeTzDU3gSgUh5AiTJQ9HVmcagp6ehxh5Y7lPn67c8XElcxB0tkbp67QOi9lmctzilIPSDIHn7busOLmpchkghv7Y8oXPSxigWkLUPePJVAyBpFsHz_zOce5a_jPugN38_Y48mRKmeBCU5xIpKLzlCyjWhhOGEnbyGi-C-plXyUWBLSWNPBPQkEC44wr_dgP2v0oO1tKpJPZUEqYrMtguteTSssovkAJ77A1qEXyJNcOH--6C75FAYjB1eQ2kj_PVrZ5cSVswlDxP4bglN4FQjnjHNrauTY0zzy66np_JCiDjW2Pjk_IVREON1tpARtWd0OBCC_FX3Ec1hwGW5Kii1fZVP2LqcULUWWXoTY6IlxyiQKNvkgX-m5Txcfo83r3PDtn2iCVGsCtg5U_lvwVJQQ8eMppaPM6w3WZxymkN3RRbI8MtoXvIk3Tnaz0SN2FW59x8YTBcbD49V1C7Ms7xRXJXO_eDGjrgZmPD_kj47_1reuXRBFQM0y5CFHDHy1o3iEy8FDaC7wbzfoos_sp71Gp_nANC-AaSg5gMC5naJVP_GDv_OWHmTx70fgOXdcxAa49ukMOWly_fTcMy7j4WSX1LnraXdmCXQtavwAwFov-FA02UHxQIxvCtkWgCPB0ir2HkK5L4Qe1PGoEOqmwpPiAjnYLzsYaqPptI5Fa9o6QV8nNcgXeuaW6I_kb3a0xRuMG8SkJKWNAw2Bn2rAwIpXtCfnXSv4WW5DJJbYkcMvp8TmZKKjdeaDnAPU_hnBqJg9bzAbM7NXdZbq0eK-oiwtb9l26Ea3ghZ5S8JligesvIKV3r7oo0H5rZs4_P6rPuJhKM75GK7-r30HHpcJ3VEglPdeewuVUwuuJHVDlxzN-pprdALvJGpQ8d_dxBCZCHcgNhWhCZprBuRc9mqahh4EyAyULexnw1jh-mzz0TZaQRvLUMmASL86ZhKKBHpoKJwFjb-xrQhojmPd8RpMeltC-ay_NES88OpWQbbP1tA0e15042roQSarfzorr-uCi5yQHgUPbnn3Y2mXwkHkH30IL01r1d-1KW-647KQuzw8erZcIZMnEDGE21qVYKXlw4oAB6Ums5slgDPsCtTvydolKtOHHslQCEquuPBgNS1my2NvWhQpYJ1MiRhqWJPvUoXBADCqvvifMuuXcJ8hD7ITJlQSUgs6mkbV8xDM7aWorDUB8_V-M9PbZ6TOZJFEW8dyKdnXOCfhQBd_2shVOUKlRPC6o6KOlx6VTx5vetz8yC8FGygOJ1ERW3_O8C9LpSSI5dUKINV1IlbUq7akCLihBW0vnpAE-6JM1jpzw0ORC0Jn8_SSij-ud3WMjjYusIGSux07DLrzsscu4CZjBjGTPLZ_y1jYoYFixFsSnHLOMwdiSVdUyJ50IuC8Fl6q8EcNKrGKeJCElUpJuhPUOEQoItKw8kKmj0fX8kbOBYdt8WMZkOY7NsDEEvuSWJ3aMy7MaRyuf0VXlLqgBZ6MQQ_UFMvoWivoUe0ESaSiXoXlkPZW6439C6DVU_puc70c0PkOCD0yz8GAWjH6nskX3x46TuOVvaT-52A_QC71lVwtAjLor1N2Quolzx_5Vs.Wl7iLOcfLyfCR7tSuJb2Sw">
#     <meta name="ajs-synchrony-service-uri" content="https://synchrony.atlassian.com/v1">
#     <meta name="ajs-synchrony-resources-uri" content="https://synchrony-cdn.atlassian.com/resources">
#     <meta name="ajs-synchrony-app-id" content="-decf0708-113d-3ad9-9ff1-3faa66cec6d9">
#     <meta name="ajs-synchrony-expiry" content="1526538453">
#     <meta name="ajs-use-xhr-fallback" content="false">
#
#             		    <meta name="ajs-max-thumb-width" content="300">
# 		    <meta name="ajs-max-thumb-height" content="300">
# 		    <meta name="ajs-can-send-email" content="true">
# 		    <meta name="ajs-is-dev-mode" content="false">
# 		    <meta name="ajs-draft-save-interval" content="30000">
# 		    <meta name="ajs-show-hidden-user-macros" content="false">
# 		    <meta name="ajs-is-admin" content="false">
# 		    <meta name="ajs-confluence.prefs.editor.disable.autocomplete" content="false">
# 		    <meta name="ajs-confluence.prefs.editor.disable.autoformat" content="false">
# 		    <meta name="ajs-heartbeat-interval" content="60000">
#  </script>
#  <script id="table-form-template" title="tableForm" type="text/x-template">
#   <form id="tinymce-table-form" class="aui">
#         <div class="field-group">
#             <label for="rows">Rows</label>
#             <input id="rows" name="rows" type="text" size="3" autocomplete="off" value="{0}">
#         </div>
#         <div class="field-group">
#             <label for="cols">Columns</label>
#             <input id="cols" name="cols" type="text" size="3" autocomplete="off" value="{1}">
#         </div>
#         <div class="field-group hidden">
#             <input id="width" type="hidden" name="width" value="">
#             <label for="width">Width</label>
#         </div>
#         <div class="group">
#             <div class="checkbox">
#                 <input id="table-heading-checkbox" class="checkbox" type="checkbox" name="heading" checked="checked" value="true">
#                 <label for="table-heading-checkbox">First row is heading</label>
#             </div>
#         </div>
#         <div class="group hidden">
#             <div class="checkbox">
#                 <input id="table-equal-width-columns-checkbox" class="checkbox" type="checkbox" name="equal-width-columns" value="false">
#                 <label for="table-equal-width-columns-checkbox">Equal width columns</label>
#             </div>
#         </div>
#     </form>
#  </script>
#  <input id="draftId" name="draftId" type="hidden" value="187433002"/>
#  <input id="originalVersion" name="originalVersion" type="hidden" value="13"/>
#  <input id="syncRev" name="syncRev" type="hidden" value="1.confluence$content$187301909.51"/>
#  <input name="atl_token" type="hidden" value="9b1c2e97cdf764fd895d016d766ba541809fc0fc"/>
# </div>
# <div class="aui-inline-dialog" id="inline-dialog-selection-action-panel" style="left: 589.533px; right: auto; top: 1425.5px; display: none;">
#  <div class="aui-inline-dialog-contents contents" style="width: auto; max-height: 522px;" unselectable="on">
#   <button class="aui-button aui-button-compact aui-button-subtle" data-key="com.atlassian.confluence.plugins.confluence-inline-comments:create-inline-comment" original-title="Add inline comment" style="display: inline-block;">
#    <span class="aui-icon aui-icon-small aui-iconfont-comment">
#    </span>
#   </button>
#   <button class="aui-button aui-button-compact aui-button-subtle" data-key="com.atlassian.confluence.plugins.confluence-jira-content:create-JIRA-issue-summary" original-title="Create JIRA issue" style="display: inline-block;">
#    <span class="aui-icon aui-icon-small aui-iconfont-jira">
#    </span>
#   </button>
#  </div>
#  <div class="aui-inline-dialog-arrow arrow aui-css-arrow aui-bottom-arrow" id="arrow-selection-action-panel" style="position: absolute; left: 33.5px; right: auto; top: 36px;" unselectable="on">
#  </div>
# </div>
# <div id="fileuploadShim" style="position: relative; z-index: 0;">
# </div>
# <div class="plupload html5" id="p1cdjjg576pc51l3n1uvn1q9h12jb0_html5_container" style="position: absolute; background: transparent none repeat scroll 0% 0%; width: 1338px; height: 0px; overflow: hidden; z-index: -1; opacity: 0; top: 696px; left: 0px;">
#  <input accept="" id="p1cdjjg576pc51l3n1uvn1q9h12jb0_html5" multiple="multiple" style="font-size: 999px; position: absolute; width: 100%; height: 100%;" type="file"/>
# </div>
# <div class="ajs-content-hover aui-box-shadow" id="content-hover-1" style="display: none;">
#  <div class="contents" style="width: 300px;">
#  </div>
# </div>
# <div class="" id="action-dialog-target" style="top: 1469.5px; height: 17px; left: 589.533px; width: 243.85px; display: none;">
# </div>
# <span>
#  <div class="cxGWJB">
#   <h1 class="kyFGMX">
#    Flag notifications
#   </h1>
#   <div class="RTdSn">
#   </div>
#  </div>
# </span>
# <div class="ajs-content-hover aui-box-shadow" id="content-hover-2" style="display: none;">
#  <div class="contents" style="width: 300px;">
#  </div>
# </div>
# <div class="ajs-content-hover aui-box-shadow" id="content-hover-3" style="display: none;">
#  <div class="contents" style="width: 300px;">
#  </div>
# </div>
# <div class="ajs-content-hover aui-box-shadow" id="content-hover-4" style="display: none;">
#  <div class="contents" style="width: 300px;">
#  </div>
# </div>
# <div class="aui-message error general-notice" id="inline-tasks-notice" style="display: block;">
#  Oops! Your task change couldn't be saved.
#  <br/>
#  There could be a few reasons for this.
#  <a class="notice-close" href="#">
#   Dismiss
#  </a>
# </div>

# %% [markdown]
# ### Retrieving title

# %%
soup.find("h1").text
# Out:
# 'Project Canvas Template'

# %% [markdown]
# ### Multiple attributes can be used to find a cell however this method is unreliable

# %%
types_of_analytics_ul = soup.find("td", {"class":"confluenceTd", "colspan":"6"}).find("ul")

# %%
types_of_analytics_list_items = types_of_analytics_ul.find_all("li")

# %% [markdown]
# ### Dealing with checkboxes in confluence

# %%
for item in types_of_analytics_list_items:
    
    class_item = item.get("class")
    
    if class_item == ["checked"]:
        print("Checked:", item.find("span").text)
    else:
        print("Unchecked:", item.find("span").text)
# Out:
# Checked: Prescriptive
# Unchecked: Predictive
# Unchecked: Diagnostic
# Unchecked: Descriptive

# %% [markdown]
# ### Targetting Building Blocks Outcomes Checklist

# %%
all_confluenceTd = soup.find_all("td", {"class":"confluenceTd"})
for block in all_confluenceTd:
    
    #print(block.prettify(),"\n","|"*60)
    h3 = block.find("h3")
    if h3 is not None:
        h3_text = h3.text
        
        if h3_text == "Building Blocks Outcomes:":
            for list_item in block.find("ul",{"class":"inline-task-list"}).find_all("li"):
                if list_item.get("class") == ["checked"]:
                    print("Checked:", list_item.text)
# Out:
# Checked: Jobs Now
# Checked: Fairness and Equity

# %% [markdown]
# ### Targetting Problem Summary Box

# %%
all_confluenceTd = soup.find_all("td", {"class":"confluenceTd"})

for block in all_confluenceTd:
    
    h3 = block.find("h3")
    
    if h3 is not None:
        
        h3_text = h3.text
        h3_text_lower_strip = h3_text.strip().lower()
        if h3_text_lower_strip == "problem summary:":
            text_block = block.text.strip()
            while "  " in text_block:
                text_block.replace("  "," ")
            print(text_block)
# Out:
# Problem Summary: e.g Supporting the financial sustainability of government debt relative to revenue is a key priority for Government. Over the next four years:traffic cameras and other fines are expected to net $3.4 billion for governmentrevenue from speed and red light cameras alone are expected to be $393 million in 2017-18, increasing to $421 million by 2020-21the budget also estimates revenue from on-the-spot fines and toll road evasion will continue to growthere are currently approximately $2 billion unpaid fines with the average being greater than 1 year oldWith these estimates in mind, recovery of fines is a key priority area for government, which will be achieved by smart and effect revenue collection from fines through enforcement and recovery activities.

# %% [markdown]
# ### Targetting macro buttons

# %%
macro_button = soup.find("span", {"class":"status-macro"})

# %%
macro_button.text
# Out:
# 'GREEN'

# %% [markdown]
# ### Pulling text from ordered (numbered) lists ("ol")

# %%
ordered_list = soup.find("ol")
print(ordered_list.prettify())
# Out:
# <ol>
#  <li>
#   <span style="color: rgb(0,0,255);">
#    <em>
#     Reduce aged debt by 10% within 12 months
#    </em>
#   </span>
#  </li>
#  <li>
#   <span style="color: rgb(0,0,255);">
#    <em>
#     Reduce average age of overdue fees to less than 1 year within 6 months
#    </em>
#   </span>
#  </li>
#  <li>
#   <span style="color: rgb(0,0,255);">
#    <em>
#     Reduce operational costs by 10% by 2020
#    </em>
#   </span>
#  </li>
# </ol>

# %%
for list_item in ordered_list:
    print(list_item.text)
# Out:
# Reduce aged debt by 10% within 12 months
# Reduce average age of overdue fees to less than 1 year within 6 months
# Reduce operational costs by 10% by 2020

# %% [markdown]
# ### Targetting "Benefits:" box, using h3 tag as an identifier

# %%
all_confluenceTd = soup.find_all("td", {"class":"confluenceTd"})

for block in all_confluenceTd:
    
    #print(block.prettify(),"\n","|"*60)
    h3 = block.find("h3")
    if h3 is not None:
        h3_text = h3.text
        
        if h3_text == "Benefits:":
            for list_item in block.find("ul").find_all("li"):
                print(list_item.text)
# Out:
# Advance IMES's self-service analytics capabilities
# Reduce aged debt
# Reduce operational costs of managing and collecting
# Change behaviour of future defendants

# %% [markdown]
# ### Pulling text from bullet point lists ("ul")

# %%
project_team_box = soup.find("td", {"class":"confluenceTd",
                                   "colspan":"7",
                                   "rowspan":"2"})

# %%
print(project_team_box.prettify())
# Out:
# <td class="confluenceTd" colspan="7" rowspan="2">
#  <h3 id="ProjectCanvasTemplate-ProjectTeam:">
#   <span style="color: rgb(153,51,102);">
#    Project Team:
#   </span>
#  </h3>
#  <ul>
#   <li>
#    <em>
#     <span style="color: rgb(0,0,255);">
#      'Name'
#     </span>
#    </em>
#    - Analytics Manager
#   </li>
#   <li>
#    <em>
#     <span style="color: rgb(0,0,255);">
#      'Name'
#     </span>
#     -
#     <span style="color: rgb(0,0,255);">
#      'Position Title'
#     </span>
#    </em>
#   </li>
#   <li>
#    <em>
#     <span style="color: rgb(0,0,255);">
#      'Name'
#     </span>
#     -
#     <span style="color: rgb(0,0,255);">
#      'Position Title'
#     </span>
#    </em>
#   </li>
#  </ul>
# </td>

# %%
project_team_ul = project_team_box.find("ul")
print(project_team_ul.prettify())
# Out:
# <ul>
#  <li>
#   <em>
#    <span style="color: rgb(0,0,255);">
#     'Name'
#    </span>
#   </em>
#   - Analytics Manager
#  </li>
#  <li>
#   <em>
#    <span style="color: rgb(0,0,255);">
#     'Name'
#    </span>
#    -
#    <span style="color: rgb(0,0,255);">
#     'Position Title'
#    </span>
#   </em>
#  </li>
#  <li>
#   <em>
#    <span style="color: rgb(0,0,255);">
#     'Name'
#    </span>
#    -
#    <span style="color: rgb(0,0,255);">
#     'Position Title'
#    </span>
#   </em>
#  </li>
# </ul>

# %%
for list_item in project_team_ul:
    print(list_item.text)
# Out:
# 'Name' - Analytics Manager
# 'Name' - 'Position Title'
# 'Name' - 'Position Title'
