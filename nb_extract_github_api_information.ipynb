# %% [markdown]
# # Extract data from github apis page
# - https://github.com/toddmotto/public-apis

# %% [markdown]
# ## Import modules

# %%
import requests
import bs4
import pandas
import numpy
import datetime

# %% [markdown]
# ##  Read in data using requests and pandas

# %%
path = "https://github.com/toddmotto/public-apis"

# %%
request = requests.get(path)

# %%
request.status_code
# Out:
# 200

# %%
requesttext = request.text

# %%
data = pandas.read_html(requesttext)

# %% [markdown]
# ## Check shape of each dataframe
# - Each dataframe appears to have 6 columns except the first, so lets remove it.

# %% [markdown]
# ### Found 47 tables

# %%
len(data)
# Out:
# 47

# %%
for dataframe in data:
    print(dataframe.shape)
# Out:
# (6, 4)
# (11, 6)
# (4, 6)
# (6, 6)
# (8, 6)
# (7, 6)
# (9, 6)
# (9, 6)
# (6, 6)
# (3, 6)
# (20, 6)
# (6, 6)
# (8, 6)
# (39, 6)
# (3, 6)
# (10, 6)
# (5, 6)
# (3, 6)
# (9, 6)
# (13, 6)
# (6, 6)
# (33, 6)
# (35, 6)
# (23, 6)
# (11, 6)
# (15, 6)
# (6, 6)
# (19, 6)
# (8, 6)
# (23, 6)
# (3, 6)
# (3, 6)
# (8, 6)
# (11, 6)
# (16, 6)
# (4, 6)
# (4, 6)
# (24, 6)
# (16, 6)
# (14, 6)
# (5, 6)
# (3, 6)
# (50, 6)
# (4, 6)
# (4, 6)
# (13, 6)
# (9, 6)

# %%
data_list = data[1:]

# %%
full_data = pandas.concat(data_list, axis = 0)

# %%
full_data.shape
# Out:
# (549, 6)

# %% [markdown]
# ### Inspecting the full data

# %%
full_data.head()
# Out:
#         API                             Description    Auth HTTPS     CORS  \
# 0      Cats            Pictures of cats from Tumblr      No   Yes  Unknown
# 1      Dogs      Based on the Stanford Dogs Dataset      No   Yes  Unknown
# 2   HTTPCat               Cat for every HTTP Status      No   Yes  Unknown
# 3      IUCN     IUCN Red List of Threatened Species  apiKey    No  Unknown
# 4  Movebank  Movement and Migration data of animals      No   Yes  Unknown
#
#   Link
# 0  Go!
# 1  Go!
# 2  Go!
# 3  Go!
# 4  Go!

# %% [markdown]
# ### Take subset of full data containing only no auth

# %%
only_no_auth_data = full_data[full_data["Auth"] == "No"]

# %%
only_no_auth_data.shape
# Out:
# (257, 6)

# %% [markdown]
# ### Links do not work using pandas method, switch to bs4 method

# %%
only_no_auth_data.head()
# Out:
#          API                             Description Auth HTTPS     CORS Link
# 0       Cats            Pictures of cats from Tumblr   No   Yes  Unknown  Go!
# 1       Dogs      Based on the Stanford Dogs Dataset   No   Yes  Unknown  Go!
# 2    HTTPCat               Cat for every HTTP Status   No   Yes  Unknown  Go!
# 4   Movebank  Movement and Migration data of animals   No   Yes  Unknown  Go!
# 6  RandomCat                 Random pictures of cats   No   Yes      Yes  Go!

# %% [markdown]
# ### Create bs4 soup object

# %%
soup = bs4.BeautifulSoup(requesttext, "lxml")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://assets-cdn.github.com" rel="dns-prefetch"/>
#   <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/frameworks-73f533b7cc08a9d040e601cfd38fa585.css" integrity="sha512-pCRDtdb3GlUU48h+oRJVA8f0GddrLnU97wB7mHQ7q6c40vMbMMZsFdk0IMhkUFRqw1M/y4EkWxtaKwfeFezOkQ==" media="all" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/github-97d6f28221b9753a523a134a3f7f3a3b.css" integrity="sha512-nUvkp2PexYbw89MufeRxmfin9hSOvl3FE5lBzRkchoc167hrmpRMEVZnnhBnPF/5j92OT1uMlqP8xYlUILCLHw==" media="all" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/site-14cf418638c848dd5bbac72b6f77dfa2.css" integrity="sha512-YBQhG++AtbZ1OJfwAkSqS9GCbbYzicxNDYKdMaLTV49eF0Lks0Bs9Egbu46uQi62AyUInQS8Cx6GGkK6uZnqFQ==" media="all" rel="stylesheet"/>
#   <meta content="width=device-width" name="viewport"/>
#   <title>
#    GitHub - toddmotto/public-apis: A collective list of public JSON APIs for use in web development.
#   </title>
#   <meta content="GitHub is where people build software. More than 28 million people use GitHub to discover, fork, and contribute to over 85 million projects." name="description"/>
#   <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
#   <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
#   <meta content="1401488693436528" property="fb:app_id"/>
#   <meta content="https://avatars1.githubusercontent.com/u/1655968?s=400&amp;v=4" property="og:image"/>
#   <meta content="GitHub" property="og:site_name"/>
#   <meta content="object" property="og:type"/>
#   <meta content="toddmotto/public-apis" property="og:title"/>
#   <meta content="https://github.com/toddmotto/public-apis" property="og:url"/>
#   <meta content="public-apis - A collective list of public JSON APIs for use in web development." property="og:description"/>
#   <link href="https://assets-cdn.github.com/" rel="assets"/>
#   <meta content="1000" name="pjax-timeout"/>
#   <meta content="F615:1A7A:177276D:23BE6A4:5B3B059F" data-pjax-transient="" name="request-id"/>
#   <meta data-pjax-transient="" name="selected-link" value="repo_source"/>
#   <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
#   <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
#   <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
#   <meta content="UA-3769691-2" name="google-analytics"/>
#   <meta content="collector.githubapp.com" name="octolytics-host"/>
#   <meta content="github" name="octolytics-app-id"/>
#   <meta content="https://collector.githubapp.com/github-external/browser_event" name="octolytics-event-url"/>
#   <meta content="F615:1A7A:177276D:23BE6A4:5B3B059F" name="octolytics-dimension-request_id"/>
#   <meta content="sea" name="octolytics-dimension-region_edge"/>
#   <meta content="iad" name="octolytics-dimension-region_render"/>
#   <meta content="/&lt;user-name&gt;/&lt;repo-name&gt;" data-pjax-transient="true" name="analytics-location"/>
#   <meta class="js-ga-set" content="Logged Out" name="dimension1"/>
#   <meta content="github.com" name="hostname"/>
#   <meta content="" name="user-login"/>
#   <meta content="github.com" name="expected-hostname"/>
#   <meta content="" name="js-proxy-site-detection-payload"/>
#   <meta content="UNIVERSE_BANNER,FREE_TRIALS,MARKETPLACE_INSIGHTS,MARKETPLACE_SEARCH,MARKETPLACE_INSIGHTS_CONVERSION_PERCENTAGES" name="enabled-features"/>
#   <meta content="ca517c80306d9628927b2839a6d4657aa3bf1d5e" name="html-safe-nonce"/>
#   <meta content="1da61b0620cf61a6fdb468d1bdb7e064" http-equiv="x-pjax-version"/>
#   <link href="https://github.com/toddmotto/public-apis/commits/master.atom" rel="alternate" title="Recent Commits to public-apis:master" type="application/atom+xml"/>
#   <meta content="public-apis - A collective list of public JSON APIs for use in web development." name="description"/>
#   <meta content="github.com/toddmotto/public-apis git https://github.com/toddmotto/public-apis.git" name="go-import"/>
#   <meta content="1655968" name="octolytics-dimension-user_id"/>
#   <meta content="toddmotto" name="octolytics-dimension-user_login"/>
#   <meta content="54346799" name="octolytics-dimension-repository_id"/>
#   <meta content="toddmotto/public-apis" name="octolytics-dimension-repository_nwo"/>
#   <meta content="true" name="octolytics-dimension-repository_public"/>
#   <meta content="false" name="octolytics-dimension-repository_is_fork"/>
#   <meta content="54346799" name="octolytics-dimension-repository_network_root_id"/>
#   <meta content="toddmotto/public-apis" name="octolytics-dimension-repository_network_root_nwo"/>
#   <meta content="false" name="octolytics-dimension-repository_explore_github_marketplace_ci_cta_shown"/>
#   <link data-pjax-transient="" href="https://github.com/toddmotto/public-apis" rel="canonical"/>
#   <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
#   <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
#   <link color="#000000" href="https://assets-cdn.github.com/pinned-octocat.svg" rel="mask-icon"/>
#   <link class="js-site-favicon" href="https://assets-cdn.github.com/favicon.ico" rel="icon" type="image/x-icon"/>
#   <meta content="#1e2327" name="theme-color"/>
#   <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
#  </head>
#  <body class="logged-out env-production">
#   <div class="position-relative js-header-wrapper ">
#    <a class="px-2 py-4 bg-blue text-white show-on-focus js-skip-to-content" href="#start-of-content" tabindex="1">
#     Skip to content
#    </a>
#    <div class="pjax-loader-bar" id="js-pjax-loader-bar">
#     <div class="progress">
#     </div>
#    </div>
#    <header class="Header header-logged-out position-relative f4 py-3" role="banner">
#     <div class="container-lg d-flex px-3">
#      <div class="d-flex flex-justify-between flex-items-center">
#       <a aria-label="Homepage" class="header-logo-invertocat my-0" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
#        <svg aria-hidden="true" class="octicon octicon-mark-github" height="32" version="1.1" viewbox="0 0 16 16" width="32">
#         <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0 0 16 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd">
#         </path>
#        </svg>
#       </a>
#      </div>
#      <div class="HeaderMenu HeaderMenu--bright d-flex flex-justify-between flex-auto">
#       <nav class="mt-0">
#        <ul class="d-flex list-style-none">
#         <li class="ml-2">
#          <a class="js-selected-navigation-item HeaderNavlink px-0 py-2 m-0" data-ga-click="Header, click, Nav menu - item:features" data-selected-links="/features /features/project-management /features/code-review /features/project-management /features/integrations /features" href="/features">
#           Features
#          </a>
#         </li>
#         <li class="ml-4">
#          <a class="js-selected-navigation-item HeaderNavlink px-0 py-2 m-0" data-ga-click="Header, click, Nav menu - item:business" data-selected-links="/business /business/security /business/customers /business" href="/business">
#           Business
#          </a>
#         </li>
#         <li class="ml-4">
#          <a class="js-selected-navigation-item HeaderNavlink px-0 py-2 m-0" data-ga-click="Header, click, Nav menu - item:explore" data-selected-links="/explore /trending /trending/developers /integrations /integrations/feature/code /integrations/feature/collaborate /integrations/feature/ship showcases showcases_search showcases_landing /explore" href="/explore">
#           Explore
#          </a>
#         </li>
#         <li class="ml-4">
#          <a class="js-selected-navigation-item HeaderNavlink px-0 py-2 m-0" data-ga-click="Header, click, Nav menu - item:marketplace" data-selected-links=" /marketplace" href="/marketplace">
#           Marketplace
#          </a>
#         </li>
#         <li class="ml-4">
#          <a class="js-selected-navigation-item HeaderNavlink px-0 py-2 m-0" data-ga-click="Header, click, Nav menu - item:pricing" data-selected-links="/pricing /pricing/developer /pricing/team /pricing/business-hosted /pricing/business-enterprise /pricing" href="/pricing">
#           Pricing
#          </a>
#         </li>
#        </ul>
#       </nav>
#       <div class="d-flex">
#        <div class="d-lg-flex flex-items-center mr-3">
#         <div aria-expanded="true" aria-haspopup="listbox" aria-label="Search or jump to" aria-owns="jump-to-results" class="header-search scoped-search site-scoped-search js-site-search position-relative js-jump-to" role="search combobox">
#          <div class="position-relative">
#           <!-- '"` -->
#           <!-- </textarea></xmp> -->
#           <form accept-charset="UTF-8" action="/toddmotto/public-apis/search" class="js-site-search-form" data-scope-id="54346799" data-scope-type="Repository" data-scoped-search-url="/toddmotto/public-apis/search" data-unscoped-search-url="/search" method="get">
#            <input name="utf8" type="hidden" value="✓"/>
#            <label class="form-control header-search-wrapper header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center js-chromeless-input-container">
#             <input aria-autocomplete="list" aria-controls="jump-to-results" autocapitalize="off" autocomplete="off" class="form-control header-search-input jump-to-field js-jump-to-field js-site-search-focus js-site-search-field is-clearable" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations#csrf-token=iZpgPmyt9lJmE1QX6XwIVraIeBqmced80nZmtsVhe7GA1CnETIVuzf9NFu8mlYrWsFUM8bXu1iK9TN2HeMZfeg==" data-scoped-placeholder="Search" data-unscoped-placeholder="Search GitHub" name="q" placeholder="Search" spellcheck="false" type="text" value=""/>
#             <input class="js-site-search-type-field" name="type" type="hidden"/>
#             <img alt="" class="mr-2 header-search-key-slash" src="https://assets-cdn.github.com/images/search-shortcut-hint.svg"/>
#             <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
#              <ul class="d-none js-jump-to-suggestions-template-container">
#               <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item">
#                <a class="no-underline d-flex flex-auto flex-items-center p-2 jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open" href="" tabindex="-1">
#                 <div class="jump-to-octicon js-jump-to-octicon mr-2 text-center d-none">
#                 </div>
#                 <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar" height="28" src="" width="28"/>
#                 <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden no-wrap css-truncate css-truncate-target">
#                 </div>
#                 <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
#                  <span aria-label="in this repository" class="js-jump-to-badge-search-text-default d-none">
#                   In this repository
#                  </span>
#                  <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#                   All GitHub
#                  </span>
#                  <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">
#                   ↵
#                  </span>
#                 </div>
#                 <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#                  Jump to
#                  <span class="d-inline-block ml-1 v-align-middle">
#                   ↵
#                  </span>
#                 </div>
#                </a>
#               </li>
#               <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-repo-octicon-template" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 12 16" width="16">
#                <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#                </path>
#               </svg>
#               <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-project-octicon-template" height="16" role="img" title="Project" version="1.1" viewbox="0 0 15 16" width="16">
#                <path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h13a1 1 0 0 0 1-1V1a1 1 0 0 0-1-1z" fill-rule="evenodd">
#                </path>
#               </svg>
#               <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-search-octicon-template" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
#                <path d="M15.7 13.3l-3.81-3.83A5.93 5.93 0 0 0 13 6c0-3.31-2.69-6-6-6S1 2.69 1 6s2.69 6 6 6c1.3 0 2.48-.41 3.47-1.11l3.83 3.81c.19.2.45.3.7.3.25 0 .52-.09.7-.3a.996.996 0 0 0 0-1.41v.01zM7 10.7c-2.59 0-4.7-2.11-4.7-4.7 0-2.59 2.11-4.7 4.7-4.7 2.59 0 4.7 2.11 4.7 4.7 0 2.59-2.11 4.7-4.7 4.7z" fill-rule="evenodd">
#                </path>
#               </svg>
#              </ul>
#              <ul class="d-none js-jump-to-no-results-template-container">
#               <li class="d-flex flex-justify-center flex-items-center p-3 f5 d-none">
#                <span class="text-gray">
#                 No suggested jump to results
#                </span>
#               </li>
#              </ul>
#              <ul class="js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results">
#               <li class="d-flex flex-justify-center flex-items-center p-0 f5">
#                <img alt="Octocat Spinner Icon" class="m-2" src="https://assets-cdn.github.com/images/spinners/octocat-spinner-128.gif" width="28"/>
#               </li>
#              </ul>
#             </div>
#            </label>
#           </form>
#          </div>
#         </div>
#        </div>
#        <span class="d-inline-block">
#         <div class="HeaderNavlink px-0 py-2 m-0">
#          <a class="text-bold text-white no-underline" data-ga-click="(Logged out) Header, clicked Sign in, text:sign-in" href="/login?return_to=%2Ftoddmotto%2Fpublic-apis">
#           Sign in
#          </a>
#          <span class="text-gray">
#           or
#          </span>
#          <a class="text-bold text-white no-underline" data-ga-click="(Logged out) Header, clicked Sign up, text:sign-up" href="/join?source=header-repo">
#           Sign up
#          </a>
#         </div>
#        </span>
#       </div>
#      </div>
#     </div>
#    </header>
#   </div>
#   <div class="show-on-focus" id="start-of-content">
#   </div>
#   <div id="js-flash-container">
#   </div>
#   <div class="application-main " role="main">
#    <div class="" itemscope="" itemtype="http://schema.org/SoftwareSourceCode">
#     <div data-pjax-container="" id="js-repo-pjax-container">
#      <div class="pagehead repohead instapaper_ignore readability-menu experiment-repo-nav ">
#       <div class="repohead-details-container clearfix container">
#        <ul class="pagehead-actions">
#         <li>
#          <a aria-label="You must be signed in to watch a repository" class="btn btn-sm btn-with-count tooltipped tooltipped-n" href="/login?return_to=%2Ftoddmotto%2Fpublic-apis" rel="nofollow">
#           <svg aria-hidden="true" class="octicon octicon-eye" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#            <path d="M8.06 2C3 2 0 8 0 8s3 6 8.06 6C13 14 16 8 16 8s-3-6-7.94-6zM8 12c-2.2 0-4-1.78-4-4 0-2.2 1.8-4 4-4 2.22 0 4 1.8 4 4 0 2.22-1.78 4-4 4zm2-4c0 1.11-.89 2-2 2-1.11 0-2-.89-2-2 0-1.11.89-2 2-2 1.11 0 2 .89 2 2z" fill-rule="evenodd">
#            </path>
#           </svg>
#           Watch
#          </a>
#          <a aria-label="1337 users are watching this repository" class="social-count" href="/toddmotto/public-apis/watchers">
#           1,337
#          </a>
#         </li>
#         <li>
#          <a aria-label="You must be signed in to star a repository" class="btn btn-sm btn-with-count tooltipped tooltipped-n" href="/login?return_to=%2Ftoddmotto%2Fpublic-apis" rel="nofollow">
#           <svg aria-hidden="true" class="octicon octicon-star" height="16" version="1.1" viewbox="0 0 14 16" width="14">
#            <path d="M14 6l-4.9-.64L7 1 4.9 5.36 0 6l3.6 3.26L2.67 14 7 11.67 11.33 14l-.93-4.74L14 6z" fill-rule="evenodd">
#            </path>
#           </svg>
#           Star
#          </a>
#          <a aria-label="39007 users starred this repository" class="social-count js-social-count" href="/toddmotto/public-apis/stargazers">
#           39,007
#          </a>
#         </li>
#         <li>
#          <a aria-label="You must be signed in to fork a repository" class="btn btn-sm btn-with-count tooltipped tooltipped-n" href="/login?return_to=%2Ftoddmotto%2Fpublic-apis" rel="nofollow">
#           <svg aria-hidden="true" class="octicon octicon-repo-forked" height="16" version="1.1" viewbox="0 0 10 16" width="10">
#            <path d="M8 1a1.993 1.993 0 0 0-1 3.72V6L5 8 3 6V4.72A1.993 1.993 0 0 0 2 1a1.993 1.993 0 0 0-1 3.72V6.5l3 3v1.78A1.993 1.993 0 0 0 5 15a1.993 1.993 0 0 0 1-3.72V9.5l3-3V4.72A1.993 1.993 0 0 0 8 1zM2 4.2C1.34 4.2.8 3.65.8 3c0-.65.55-1.2 1.2-1.2.65 0 1.2.55 1.2 1.2 0 .65-.55 1.2-1.2 1.2zm3 10c-.66 0-1.2-.55-1.2-1.2 0-.65.55-1.2 1.2-1.2.65 0 1.2.55 1.2 1.2 0 .65-.55 1.2-1.2 1.2zm3-10c-.66 0-1.2-.55-1.2-1.2 0-.65.55-1.2 1.2-1.2.65 0 1.2.55 1.2 1.2 0 .65-.55 1.2-1.2 1.2z" fill-rule="evenodd">
#            </path>
#           </svg>
#           Fork
#          </a>
#          <a aria-label="3825 users forked this repository" class="social-count" href="/toddmotto/public-apis/network">
#           3,825
#          </a>
#         </li>
#        </ul>
#        <h1 class="public ">
#         <svg aria-hidden="true" class="octicon octicon-repo" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#          <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#          </path>
#         </svg>
#         <span class="author" itemprop="author">
#          <a class="url fn" href="/toddmotto" rel="author">
#           toddmotto
#          </a>
#         </span>
#         <!--
# -->
#         <span class="path-divider">
#          /
#         </span>
#         <!--
# -->
#         <strong itemprop="name">
#          <a data-pjax="#js-repo-pjax-container" href="/toddmotto/public-apis">
#           public-apis
#          </a>
#         </strong>
#        </h1>
#       </div>
#       <nav class="reponav js-repo-nav js-sidenav-container-pjax container" data-pjax="#js-repo-pjax-container" itemscope="" itemtype="http://schema.org/BreadcrumbList" role="navigation">
#        <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#         <a class="js-selected-navigation-item selected reponav-item" data-hotkey="g c" data-selected-links="repo_source repo_downloads repo_commits repo_releases repo_tags repo_branches repo_packages /toddmotto/public-apis" href="/toddmotto/public-apis" itemprop="url">
#          <svg aria-hidden="true" class="octicon octicon-code" height="16" version="1.1" viewbox="0 0 14 16" width="14">
#           <path d="M9.5 3L8 4.5 11.5 8 8 11.5 9.5 13 14 8 9.5 3zm-5 0L0 8l4.5 5L6 11.5 2.5 8 6 4.5 4.5 3z" fill-rule="evenodd">
#           </path>
#          </svg>
#          <span itemprop="name">
#           Code
#          </span>
#          <meta content="1" itemprop="position"/>
#         </a>
#        </span>
#        <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#         <a class="js-selected-navigation-item reponav-item" data-hotkey="g i" data-selected-links="repo_issues repo_labels repo_milestones /toddmotto/public-apis/issues" href="/toddmotto/public-apis/issues" itemprop="url">
#          <svg aria-hidden="true" class="octicon octicon-issue-opened" height="16" version="1.1" viewbox="0 0 14 16" width="14">
#           <path d="M7 2.3c3.14 0 5.7 2.56 5.7 5.7s-2.56 5.7-5.7 5.7A5.71 5.71 0 0 1 1.3 8c0-3.14 2.56-5.7 5.7-5.7zM7 1C3.14 1 0 4.14 0 8s3.14 7 7 7 7-3.14 7-7-3.14-7-7-7zm1 3H6v5h2V4zm0 6H6v2h2v-2z" fill-rule="evenodd">
#           </path>
#          </svg>
#          <span itemprop="name">
#           Issues
#          </span>
#          <span class="Counter">
#           1
#          </span>
#          <meta content="2" itemprop="position"/>
#         </a>
#        </span>
#        <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#         <a class="js-selected-navigation-item reponav-item" data-hotkey="g p" data-selected-links="repo_pulls checks /toddmotto/public-apis/pulls" href="/toddmotto/public-apis/pulls" itemprop="url">
#          <svg aria-hidden="true" class="octicon octicon-git-pull-request" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#           <path d="M11 11.28V5c-.03-.78-.34-1.47-.94-2.06C9.46 2.35 8.78 2.03 8 2H7V0L4 3l3 3V4h1c.27.02.48.11.69.31.21.2.3.42.31.69v6.28A1.993 1.993 0 0 0 10 15a1.993 1.993 0 0 0 1-3.72zm-1 2.92c-.66 0-1.2-.55-1.2-1.2 0-.65.55-1.2 1.2-1.2.65 0 1.2.55 1.2 1.2 0 .65-.55 1.2-1.2 1.2zM4 3c0-1.11-.89-2-2-2a1.993 1.993 0 0 0-1 3.72v6.56A1.993 1.993 0 0 0 2 15a1.993 1.993 0 0 0 1-3.72V4.72c.59-.34 1-.98 1-1.72zm-.8 10c0 .66-.55 1.2-1.2 1.2-.65 0-1.2-.55-1.2-1.2 0-.65.55-1.2 1.2-1.2.65 0 1.2.55 1.2 1.2zM2 4.2C1.34 4.2.8 3.65.8 3c0-.65.55-1.2 1.2-1.2.65 0 1.2.55 1.2 1.2 0 .65-.55 1.2-1.2 1.2z" fill-rule="evenodd">
#           </path>
#          </svg>
#          <span itemprop="name">
#           Pull requests
#          </span>
#          <span class="Counter">
#           4
#          </span>
#          <meta content="3" itemprop="position"/>
#         </a>
#        </span>
#        <a class="js-selected-navigation-item reponav-item" data-hotkey="g b" data-selected-links="repo_projects new_repo_project repo_project /toddmotto/public-apis/projects" href="/toddmotto/public-apis/projects">
#         <svg aria-hidden="true" class="octicon octicon-project" height="16" version="1.1" viewbox="0 0 15 16" width="15">
#          <path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h13a1 1 0 0 0 1-1V1a1 1 0 0 0-1-1z" fill-rule="evenodd">
#          </path>
#         </svg>
#         Projects
#         <span class="Counter">
#          0
#         </span>
#        </a>
#        <a class="js-selected-navigation-item reponav-item" data-selected-links="repo_graphs repo_contributors dependency_graph pulse /toddmotto/public-apis/pulse" href="/toddmotto/public-apis/pulse">
#         <svg aria-hidden="true" class="octicon octicon-graph" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#          <path d="M16 14v1H0V0h1v14h15zM5 13H3V8h2v5zm4 0H7V3h2v10zm4 0h-2V6h2v7z" fill-rule="evenodd">
#          </path>
#         </svg>
#         Insights
#        </a>
#       </nav>
#      </div>
#      <div class="container new-discussion-timeline experiment-repo-nav ">
#       <div class="repository-content ">
#        <div class="signup-prompt-bg rounded-1">
#         <div class="signup-prompt p-4 text-center mb-4 rounded-1">
#          <div class="position-relative">
#           <!-- '"` -->
#           <!-- </textarea></xmp> -->
#           <form accept-charset="UTF-8" action="/site/dismiss_signup_prompt" method="post">
#            <input name="utf8" type="hidden" value="✓"/>
#            <input name="authenticity_token" type="hidden" value="CCDsv6d+nX0iM0XcG7Y6iy+b7VtYlwwCQRQ2PzvE94r+A5cCAHxPyjv1G8sm6Gd1y2j+EQM835uztXm7eA/tKQ=="/>
#            <button class="position-absolute top-0 right-0 btn-link link-gray" data-ga-click="(Logged out) Sign up prompt, clicked Dismiss, text:dismiss" type="submit">
#             Dismiss
#            </button>
#           </form>
#           <h3 class="pt-2">
#            Join GitHub today
#           </h3>
#           <p class="col-6 mx-auto">
#            GitHub is home to over 28 million developers working together to host and review code, manage projects, and build software together.
#           </p>
#           <a class="btn btn-primary" data-ga-click="(Logged out) Sign up prompt, clicked Sign up, text:sign-up" href="/join?source=prompt-code">
#            Sign up
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="js-repo-meta-container">
#         <div class="repository-meta mb-0 mb-3 js-repo-meta-edit js-details-container ">
#          <div class="repository-meta-content col-11 mb-1">
#           <span class="col-11 text-gray-dark mr-2" itemprop="about">
#            A collective list of public JSON APIs for use in web development.
#           </span>
#           <span itemprop="url">
#            <a href="https://toddmotto.com" rel="nofollow">
#             https://toddmotto.com
#            </a>
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="overall-summary overall-summary-bottomless">
#         <div class="stats-switcher-viewport js-stats-switcher-viewport">
#          <div class="stats-switcher-wrapper">
#           <ul class="numbers-summary">
#            <li class="commits">
#             <a data-pjax="" href="/toddmotto/public-apis/commits/master">
#              <svg aria-hidden="true" class="octicon octicon-history" height="16" version="1.1" viewbox="0 0 14 16" width="14">
#               <path d="M8 13H6V6h5v2H8v5zM7 1C4.81 1 2.87 2.02 1.59 3.59L0 2v4h4L2.5 4.5C3.55 3.17 5.17 2.3 7 2.3c3.14 0 5.7 2.56 5.7 5.7s-2.56 5.7-5.7 5.7A5.71 5.71 0 0 1 1.3 8c0-.34.03-.67.09-1H.08C.03 7.33 0 7.66 0 8c0 3.86 3.14 7 7 7s7-3.14 7-7-3.14-7-7-7z" fill-rule="evenodd">
#               </path>
#              </svg>
#              <span class="num text-emphasized">
#               1,840
#              </span>
#              commits
#             </a>
#            </li>
#            <li>
#             <a data-pjax="" href="/toddmotto/public-apis/branches">
#              <svg aria-hidden="true" class="octicon octicon-git-branch" height="16" version="1.1" viewbox="0 0 10 16" width="10">
#               <path d="M10 5c0-1.11-.89-2-2-2a1.993 1.993 0 0 0-1 3.72v.3c-.02.52-.23.98-.63 1.38-.4.4-.86.61-1.38.63-.83.02-1.48.16-2 .45V4.72a1.993 1.993 0 0 0-1-3.72C.88 1 0 1.89 0 3a2 2 0 0 0 1 1.72v6.56c-.59.35-1 .99-1 1.72 0 1.11.89 2 2 2 1.11 0 2-.89 2-2 0-.53-.2-1-.53-1.36.09-.06.48-.41.59-.47.25-.11.56-.17.94-.17 1.05-.05 1.95-.45 2.75-1.25S8.95 7.77 9 6.73h-.02C9.59 6.37 10 5.73 10 5zM2 1.8c.66 0 1.2.55 1.2 1.2 0 .65-.55 1.2-1.2 1.2C1.35 4.2.8 3.65.8 3c0-.65.55-1.2 1.2-1.2zm0 12.41c-.66 0-1.2-.55-1.2-1.2 0-.65.55-1.2 1.2-1.2.65 0 1.2.55 1.2 1.2 0 .65-.55 1.2-1.2 1.2zm6-8c-.66 0-1.2-.55-1.2-1.2 0-.65.55-1.2 1.2-1.2.65 0 1.2.55 1.2 1.2 0 .65-.55 1.2-1.2 1.2z" fill-rule="evenodd">
#               </path>
#              </svg>
#              <span class="num text-emphasized">
#               2
#              </span>
#              branches
#             </a>
#            </li>
#            <li>
#             <a href="/toddmotto/public-apis/releases">
#              <svg aria-hidden="true" class="octicon octicon-tag" height="16" version="1.1" viewbox="0 0 14 16" width="14">
#               <path d="M7.685 1.72a2.49 2.49 0 0 0-1.76-.726H3.48A2.5 2.5 0 0 0 .994 3.48v2.456c0 .656.269 1.292.726 1.76l6.024 6.024a.99.99 0 0 0 1.402 0l4.563-4.563a.99.99 0 0 0 0-1.402L7.685 1.72zM2.366 7.048A1.54 1.54 0 0 1 1.9 5.925V3.48c0-.874.716-1.58 1.58-1.58h2.456c.418 0 .825.159 1.123.467l6.104 6.094-4.702 4.702-6.094-6.114zm.626-4.066h1.989v1.989H2.982V2.982h.01z" fill-rule="evenodd">
#               </path>
#              </svg>
#              <span class="num text-emphasized">
#               0
#              </span>
#              releases
#             </a>
#            </li>
#            <li>
#             <a href="/toddmotto/public-apis/graphs/contributors">
#              <svg aria-hidden="true" class="octicon octicon-organization" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#               <path d="M16 12.999c0 .439-.45 1-1 1H7.995c-.539 0-.994-.447-.995-.999H1c-.54 0-1-.561-1-1 0-2.634 3-4 3-4s.229-.409 0-1c-.841-.621-1.058-.59-1-3 .058-2.419 1.367-3 2.5-3s2.442.58 2.5 3c.058 2.41-.159 2.379-1 3-.229.59 0 1 0 1s1.549.711 2.42 2.088C9.196 9.369 10 8.999 10 8.999s.229-.409 0-1c-.841-.62-1.058-.59-1-3 .058-2.419 1.367-3 2.5-3s2.437.581 2.495 3c.059 2.41-.158 2.38-1 3-.229.59 0 1 0 1s3.005 1.366 3.005 4z" fill-rule="evenodd">
#               </path>
#              </svg>
#              <span class="num text-emphasized">
#               397
#              </span>
#              contributors
#             </a>
#            </li>
#           </ul>
#           <div class="repository-lang-stats">
#            <ol class="repository-lang-stats-numbers">
#             <li>
#              <a data-ga-click="Repository, language stats search click, location:repo overview" href="/toddmotto/public-apis/search?l=python">
#               <span class="color-block language-color" style="background-color:#3572A5;">
#               </span>
#               <span class="lang">
#                Python
#               </span>
#               <span class="percent">
#                88.6%
#               </span>
#              </a>
#             </li>
#             <li>
#              <a data-ga-click="Repository, language stats search click, location:repo overview" href="/toddmotto/public-apis/search?l=shell">
#               <span class="color-block language-color" style="background-color:#89e051;">
#               </span>
#               <span class="lang">
#                Shell
#               </span>
#               <span class="percent">
#                11.4%
#               </span>
#              </a>
#             </li>
#            </ol>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="repository-lang-stats-graph js-toggle-lang-stats" data-ga-click="Repository, language bar stats toggle, location:repo overview" title="Click for language details">
#         <span aria-label="Python 88.6%" class="language-color" itemprop="keywords" style="width:88.6%; background-color:#3572A5;">
#          Python
#         </span>
#         <span aria-label="Shell 11.4%" class="language-color" itemprop="keywords" style="width:11.4%; background-color:#89e051;">
#          Shell
#         </span>
#        </div>
#        <div class="file-navigation in-mid-page d-flex flex-items-start">
#         <div class="select-menu branch-select-menu js-menu-container js-select-menu float-left">
#          <button aria-expanded="false" aria-haspopup="true" aria-label="Switch branches or tags" class=" btn btn-sm select-menu-button js-menu-target css-truncate" data-hotkey="w" type="button">
#           <i>
#            Branch:
#           </i>
#           <span class="js-select-button css-truncate-target">
#            master
#           </span>
#          </button>
#          <div class="select-menu-modal-holder js-menu-content js-navigation-container" data-pjax="">
#           <div class="select-menu-modal">
#            <div class="select-menu-header">
#             <svg aria-label="Close" class="octicon octicon-x js-menu-close" height="16" role="img" version="1.1" viewbox="0 0 12 16" width="12">
#              <path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd">
#              </path>
#             </svg>
#             <span class="select-menu-title">
#              Switch branches/tags
#             </span>
#            </div>
#            <div class="select-menu-filters">
#             <div class="select-menu-text-filter">
#              <input aria-label="Filter branches/tags" class="form-control js-filterable-field js-navigation-enable" id="context-commitish-filter-field" placeholder="Filter branches/tags" type="text"/>
#             </div>
#             <div class="select-menu-tabs">
#              <ul>
#               <li class="select-menu-tab">
#                <a class="js-select-menu-tab" data-filter-placeholder="Filter branches/tags" data-tab-filter="branches" href="#" role="tab">
#                 Branches
#                </a>
#               </li>
#               <li class="select-menu-tab">
#                <a class="js-select-menu-tab" data-filter-placeholder="Find a tag…" data-tab-filter="tags" href="#" role="tab">
#                 Tags
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class="select-menu-list select-menu-tab-bucket js-select-menu-tab-bucket" data-tab-filter="branches" role="menu">
#             <div data-filterable-for="context-commitish-filter-field" data-filterable-type="substring">
#              <a class="select-menu-item js-navigation-item js-navigation-open " data-name="alpha-site" data-skip-pjax="true" href="/toddmotto/public-apis/tree/alpha-site" rel="nofollow">
#               <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#                <path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd">
#                </path>
#               </svg>
#               <span class="select-menu-item-text css-truncate-target js-select-menu-filter-text">
#                alpha-site
#               </span>
#              </a>
#              <a class="select-menu-item js-navigation-item js-navigation-open selected" data-name="master" data-skip-pjax="true" href="/toddmotto/public-apis/tree/master" rel="nofollow">
#               <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#                <path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd">
#                </path>
#               </svg>
#               <span class="select-menu-item-text css-truncate-target js-select-menu-filter-text">
#                master
#               </span>
#              </a>
#             </div>
#             <div class="select-menu-no-results">
#              Nothing to show
#             </div>
#            </div>
#            <div class="select-menu-list select-menu-tab-bucket js-select-menu-tab-bucket" data-tab-filter="tags">
#             <div data-filterable-for="context-commitish-filter-field" data-filterable-type="substring">
#             </div>
#             <div class="select-menu-no-results">
#              Nothing to show
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <button aria-label="You must be signed in to create a pull request" class="btn btn-sm disabled tooltipped tooltipped-n new-pull-request-btn" type="button">
#          New pull request
#         </button>
#         <div class="breadcrumb flex-auto">
#         </div>
#         <div class="BtnGroup">
#          <a class="btn btn-sm empty-icon float-right BtnGroup-item" data-ga-click="Repository, find file, location:repo overview" data-hotkey="t" data-pjax="" href="/toddmotto/public-apis/find/master">
#           Find file
#          </a>
#         </div>
#         <details class="get-repo-select-menu js-get-repo-select-menu position-relative details-overlay details-reset">
#          <summary class="btn btn-sm btn-primary">
#           Clone or download
#           <span class="dropdown-caret">
#           </span>
#          </summary>
#          <div class="position-relative">
#           <div class="get-repo-modal dropdown-menu dropdown-menu-sw pb-0 js-toggler-container js-get-repo-modal">
#            <div class="get-repo-modal-options">
#             <div class="clone-options https-clone-options">
#              <h4 class="mb-1">
#               Clone with HTTPS
#               <a class="muted-link" href="https://help.github.com/articles/which-remote-url-should-i-use" target="_blank" title="Which remote URL should I use?">
#                <svg aria-hidden="true" class="octicon octicon-question" height="16" version="1.1" viewbox="0 0 14 16" width="14">
#                 <path d="M6 10h2v2H6v-2zm4-3.5C10 8.64 8 9 8 9H6c0-.55.45-1 1-1h.5c.28 0 .5-.22.5-.5v-1c0-.28-.22-.5-.5-.5h-1c-.28 0-.5.22-.5.5V7H4c0-1.5 1.5-3 3-3s3 1 3 2.5zM7 2.3c3.14 0 5.7 2.56 5.7 5.7s-2.56 5.7-5.7 5.7A5.71 5.71 0 0 1 1.3 8c0-3.14 2.56-5.7 5.7-5.7zM7 1C3.14 1 0 4.14 0 8s3.14 7 7 7 7-3.14 7-7-3.14-7-7-7z" fill-rule="evenodd">
#                 </path>
#                </svg>
#               </a>
#              </h4>
#              <p class="mb-2 get-repo-decription-text">
#               Use Git or checkout with SVN using the web URL.
#              </p>
#              <div class="input-group">
#               <input aria-label="Clone this repository at https://github.com/toddmotto/public-apis.git" class="form-control input-monospace input-sm js-url-field" readonly="" type="text" value="https://github.com/toddmotto/public-apis.git"/>
#               <div class="input-group-button">
#                <clipboard-copy aria-label="Copy to clipboard" class="btn btn-sm" value="https://github.com/toddmotto/public-apis.git">
#                 <svg aria-hidden="true" class="octicon octicon-clippy" height="16" version="1.1" viewbox="0 0 14 16" width="14">
#                  <path d="M2 13h4v1H2v-1zm5-6H2v1h5V7zm2 3V8l-3 3 3 3v-2h5v-2H9zM4.5 9H2v1h2.5V9zM2 12h2.5v-1H2v1zm9 1h1v2c-.02.28-.11.52-.3.7-.19.18-.42.28-.7.3H1c-.55 0-1-.45-1-1V4c0-.55.45-1 1-1h3c0-1.11.89-2 2-2 1.11 0 2 .89 2 2h3c.55 0 1 .45 1 1v5h-1V6H1v9h10v-2zM2 5h8c0-.55-.45-1-1-1H8c-.55 0-1-.45-1-1s-.45-1-1-1-1 .45-1 1-.45 1-1 1H3c-.55 0-1 .45-1 1z" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                </clipboard-copy>
#               </div>
#              </div>
#             </div>
#             <div class="mt-2">
#              <a class="btn btn-outline get-repo-btn " data-ga-click="Repository, download zip, location:repo overview" href="/toddmotto/public-apis/archive/master.zip" rel="nofollow">
#               Download ZIP
#              </a>
#             </div>
#            </div>
#            <div class="js-modal-download-mac py-2 px-3 d-none">
#             <h4 class="lh-condensed mb-3">
#              Launching GitHub Desktop
#              <span class="animated-ellipsis-container">
#               <span class="animated-ellipsis">
#                ...
#               </span>
#              </span>
#             </h4>
#             <p class="text-gray">
#              If nothing happens,
#              <a href="https://desktop.github.com/">
#               download GitHub Desktop
#              </a>
#              and try again.
#             </p>
#             <p>
#              <button class="btn-link js-get-repo-modal-download-back">
#               Go back
#              </button>
#             </p>
#            </div>
#            <div class="js-modal-download-windows py-2 px-3 d-none">
#             <h4 class="lh-condensed mb-3">
#              Launching GitHub Desktop
#              <span class="animated-ellipsis-container">
#               <span class="animated-ellipsis">
#                ...
#               </span>
#              </span>
#             </h4>
#             <p class="text-gray">
#              If nothing happens,
#              <a href="https://desktop.github.com/">
#               download GitHub Desktop
#              </a>
#              and try again.
#             </p>
#             <p>
#              <button class="btn-link js-get-repo-modal-download-back">
#               Go back
#              </button>
#             </p>
#            </div>
#            <div class="js-modal-download-xcode py-2 px-3 d-none">
#             <h4 class="lh-condensed mb-3">
#              Launching Xcode
#              <span class="animated-ellipsis-container">
#               <span class="animated-ellipsis">
#                ...
#               </span>
#              </span>
#             </h4>
#             <p class="text-gray">
#              If nothing happens,
#              <a href="https://developer.apple.com/xcode/">
#               download Xcode
#              </a>
#              and try again.
#             </p>
#             <p>
#              <button class="btn-link js-get-repo-modal-download-back">
#               Go back
#              </button>
#             </p>
#            </div>
#            <div class="js-modal-download-visual-studio py-2 px-3 d-none">
#             <h4 class="lh-condensed mb-3">
#              Launching Visual Studio
#              <span class="animated-ellipsis-container">
#               <span class="animated-ellipsis">
#                ...
#               </span>
#              </span>
#             </h4>
#             <p class="text-gray">
#              If nothing happens,
#              <a href="https://visualstudio.github.com/">
#               download the GitHub extension for Visual Studio
#              </a>
#              and try again.
#             </p>
#             <p>
#              <button class="btn-link js-get-repo-modal-download-back">
#               Go back
#              </button>
#             </p>
#            </div>
#           </div>
#          </div>
#         </details>
#        </div>
#        <div class="commit-tease js-details-container Details d-flex">
#         <div class="AvatarStack flex-self-start AvatarStack--two">
#          <div aria-label="haideralipunjabi and davemachado (non-author committer)" class="AvatarStack-body">
#           <a class="avatar" data-hovercard-user-id="11888687" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" data-skip-pjax="true" href="/haideralipunjabi">
#            <img alt="@haideralipunjabi" height="20" src="https://avatars0.githubusercontent.com/u/11888687?s=60&amp;v=4" width="20"/>
#           </a>
#           <a class="avatar" data-hovercard-user-id="15134885" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" data-skip-pjax="true" href="/davemachado">
#            <img alt="@davemachado" height="20" src="https://avatars1.githubusercontent.com/u/15134885?s=60&amp;v=4" width="20"/>
#           </a>
#          </div>
#         </div>
#         <div class="flex-auto f6 no-wrap mr-3">
#          <a aria-label="View all commits by haideralipunjabi" class="commit-author tooltipped tooltipped-s user-mention" href="/toddmotto/public-apis/commits?author=haideralipunjabi">
#           haideralipunjabi
#          </a>
#          and
#          <a aria-label="View all commits by davemachado" class="commit-author tooltipped tooltipped-s user-mention" href="/toddmotto/public-apis/commits?author=davemachado">
#           davemachado
#          </a>
#          <a class="message" data-pjax="true" href="/toddmotto/public-apis/commit/2afa9404ca33639efb274b4dab337f36a7859402" title="Removed 500px API (#708)
#
# Removed 500px API as it was shutdown on June 15th.
# https://support.500px.com/hc/en-us/articles/360002435653-API-">
#           Removed 500px API (
#          </a>
#          <a class="issue-link js-issue-link" data-error-text="Failed to load issue title" data-id="337216181" data-permission-text="Issue title is private" data-url="https://github.com/toddmotto/public-apis/issues/708" href="https://github.com/toddmotto/public-apis/pull/708">
#           #708
#          </a>
#          <a class="message" data-pjax="true" href="/toddmotto/public-apis/commit/2afa9404ca33639efb274b4dab337f36a7859402" title="Removed 500px API (#708)
#
# Removed 500px API as it was shutdown on June 15th.
# https://support.500px.com/hc/en-us/articles/360002435653-API-">
#           )
#          </a>
#          <span class="hidden-text-expander inline">
#           <button aria-expanded="false" class="ellipsis-expander js-details-target" type="button">
#            …
#           </button>
#          </span>
#          <div class="commit-desc">
#           <pre class="text-small">Removed 500px API as it was shutdown on June 15th.
# <a href="https://support.500px.com/hc/en-us/articles/360002435653-API-" rel="nofollow">https://support.500px.com/hc/en-us/articles/360002435653-API-</a></pre>
#          </div>
#         </div>
#         <div class="no-wrap">
#          Latest commit
#          <a class="commit-tease-sha" data-pjax="" href="/toddmotto/public-apis/commit/2afa9404ca33639efb274b4dab337f36a7859402">
#           2afa940
#          </a>
#          <span itemprop="dateModified">
#           <relative-time datetime="2018-07-01T14:10:41Z">
#            Jul 1, 2018
#           </relative-time>
#          </span>
#         </div>
#        </div>
#        <div class="file-wrap">
#         <a class="d-none js-permalink-shortcut" data-hotkey="y" href="/toddmotto/public-apis/tree/2afa9404ca33639efb274b4dab337f36a7859402">
#          Permalink
#         </a>
#         <table class="files js-navigation-container js-active-navigation-container" data-pjax="">
#          <tbody>
#           <tr class="warning include-fragment-error">
#            <td class="icon">
#             <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#              <path d="M8.893 1.5c-.183-.31-.52-.5-.887-.5s-.703.19-.886.5L.138 13.499a.98.98 0 0 0 0 1.001c.193.31.53.501.886.501h13.964c.367 0 .704-.19.877-.5a1.03 1.03 0 0 0 .01-1.002L8.893 1.5zm.133 11.497H6.987v-2.003h2.039v2.003zm0-3.004H6.987V5.987h2.039v4.006z" fill-rule="evenodd">
#              </path>
#             </svg>
#            </td>
#            <td class="content" colspan="3">
#             Failed to load latest commit information.
#            </td>
#           </tr>
#           <tr class="js-navigation-item">
#            <td class="icon">
#             <svg aria-hidden="true" class="octicon octicon-file-directory" height="16" version="1.1" viewbox="0 0 14 16" width="14">
#              <path d="M13 4H7V3c0-.66-.31-1-1-1H1c-.55 0-1 .45-1 1v10c0 .55.45 1 1 1h12c.55 0 1-.45 1-1V5c0-.55-.45-1-1-1zM6 4H1V3h5v1z" fill-rule="evenodd">
#              </path>
#             </svg>
#             <img alt="" class="spinner" height="16" src="https://assets-cdn.github.com/images/spinners/octocat-spinner-32.gif" width="16"/>
#            </td>
#            <td class="content">
#             <span class="css-truncate css-truncate-target">
#              <a class="js-navigation-open" href="/toddmotto/public-apis/tree/master/.github" id="01777e4a9846fea5f3fcc8fe40d44680-aaf9aded3f7286509e359fdc2ab7da8385a4bc4e" title=".github">
#               .github
#              </a>
#             </span>
#            </td>
#            <td class="message">
#             <span class="css-truncate css-truncate-target">
#              <a class="message" data-pjax="true" href="/toddmotto/public-apis/commit/9bdfc79c7ea472dc3a980f3737466445826fc09e" title="Update PR Template to include squashing commits">
#               Update PR Template to include squashing commits
#              </a>
#             </span>
#            </td>
#            <td class="age">
#             <span class="css-truncate css-truncate-target">
#              <time-ago datetime="2018-04-21T18:15:54Z">
#               Apr 21, 2018
#              </time-ago>
#             </span>
#            </td>
#           </tr>
# ...
#             <td>
#              Star Wars Information
#             </td>
#             <td>
#              No
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              Unknown
#             </td>
#             <td>
#              <a href="https://swapi.co" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              TMDb
#             </td>
#             <td>
#              Community-based movie data
#             </td>
#             <td>
#              <code>
#               apiKey
#              </code>
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              Unknown
#             </td>
#             <td>
#              <a href="https://www.themoviedb.org/documentation/api" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              TVDB
#             </td>
#             <td>
#              Television data
#             </td>
#             <td>
#              <code>
#               apiKey
#              </code>
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              Unknown
#             </td>
#             <td>
#              <a href="https://api.thetvdb.com/swagger" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              TVMaze
#             </td>
#             <td>
#              TV Show Data
#             </td>
#             <td>
#              No
#             </td>
#             <td>
#              No
#             </td>
#             <td>
#              Unknown
#             </td>
#             <td>
#              <a href="http://www.tvmaze.com/api" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              Utelly
#             </td>
#             <td>
#              Check where a tv show or movie is available
#             </td>
#             <td>
#              <code>
#               X-Mashape-Key
#              </code>
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              Unknown
#             </td>
#             <td>
#              <a href="https://market.mashape.com/utelly/utelly" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              Vimeo
#             </td>
#             <td>
#              Vimeo Developer API
#             </td>
#             <td>
#              <code>
#               OAuth
#              </code>
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              Unknown
#             </td>
#             <td>
#              <a href="https://developer.vimeo.com/" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              YouTube
#             </td>
#             <td>
#              Add YouTube functionality to your sites and apps
#             </td>
#             <td>
#              <code>
#               OAuth
#              </code>
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              Unknown
#             </td>
#             <td>
#              <a href="https://developers.google.com/youtube/" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#          <h3>
#           <a aria-hidden="true" class="anchor" href="#weather" id="user-content-weather">
#            <svg aria-hidden="true" class="octicon octicon-link" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#             <path d="M4 9h1v1H4c-1.5 0-3-1.69-3-3.5S2.55 3 4 3h4c1.45 0 3 1.69 3 3.5 0 1.41-.91 2.72-2 3.25V8.59c.58-.45 1-1.27 1-2.09C10 5.22 8.98 4 8 4H4c-.98 0-2 1.22-2 2.5S3 9 4 9zm9-3h-1v1h1c1 0 2 1.22 2 2.5S13.98 12 13 12H9c-.98 0-2-1.22-2-2.5 0-.83.42-1.64 1-2.09V6.25c-1.09.53-2 1.84-2 3.25C6 11.31 7.55 13 9 13h4c1.45 0 3-1.69 3-3.5S14.5 6 13 6z" fill-rule="evenodd">
#             </path>
#            </svg>
#           </a>
#           Weather
#          </h3>
#          <table>
#           <thead>
#            <tr>
#             <th>
#              API
#             </th>
#             <th>
#              Description
#             </th>
#             <th>
#              Auth
#             </th>
#             <th>
#              HTTPS
#             </th>
#             <th>
#              CORS
#             </th>
#             <th>
#              Link
#             </th>
#            </tr>
#           </thead>
#           <tbody>
#            <tr>
#             <td>
#              ClimaCell Micro Weather
#             </td>
#             <td>
#              Historical, real-time, and nowcast weather data
#             </td>
#             <td>
#              <code>
#               apiKey
#              </code>
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              <a href="https://developer.climacell.co" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              Dark Sky
#             </td>
#             <td>
#              Weather
#             </td>
#             <td>
#              <code>
#               apiKey
#              </code>
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              No
#             </td>
#             <td>
#              <a href="https://darksky.net/dev/" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              MetaWeather
#             </td>
#             <td>
#              Weather
#             </td>
#             <td>
#              No
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              No
#             </td>
#             <td>
#              <a href="https://www.metaweather.com/api/" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              ODWeather
#             </td>
#             <td>
#              Weather and weather webcams
#             </td>
#             <td>
#              No
#             </td>
#             <td>
#              No
#             </td>
#             <td>
#              Unknown
#             </td>
#             <td>
#              <a href="http://api.oceandrivers.com/static/docs.html" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              OpenUV
#             </td>
#             <td>
#              Real-time UV Index Forecast
#             </td>
#             <td>
#              <code>
#               apiKey
#              </code>
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              Unknown
#             </td>
#             <td>
#              <a href="https://www.openuv.io" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              OpenWeatherMap
#             </td>
#             <td>
#              Weather
#             </td>
#             <td>
#              <code>
#               apiKey
#              </code>
#             </td>
#             <td>
#              No
#             </td>
#             <td>
#              Unknown
#             </td>
#             <td>
#              <a href="http://openweathermap.org/api" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              Storm Glass
#             </td>
#             <td>
#              Global marine weather from multiple sources
#             </td>
#             <td>
#              <code>
#               apiKey
#              </code>
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              <a href="https://stormglass.io/" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              Weatherbit
#             </td>
#             <td>
#              Weather
#             </td>
#             <td>
#              <code>
#               apiKey
#              </code>
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              Unknown
#             </td>
#             <td>
#              <a href="https://www.weatherbit.io/api" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              Yahoo! Weather
#             </td>
#             <td>
#              Weather
#             </td>
#             <td>
#              <code>
#               apiKey
#              </code>
#             </td>
#             <td>
#              Yes
#             </td>
#             <td>
#              Unknown
#             </td>
#             <td>
#              <a href="https://developer.yahoo.com/weather/" rel="nofollow">
#               Go!
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </article>
#        </div>
#       </div>
#       <div class="modal-backdrop js-touch-events">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="footer container-lg px-3" role="contentinfo">
#    <div class="position-relative d-flex flex-justify-between pt-6 pb-2 mt-6 f6 text-gray border-top border-gray-light ">
#     <ul class="list-style-none d-flex flex-wrap ">
#      <li class="mr-3">
#       © 2018
#       <span title="0.23725s from unicorn-59c99d44b8-jhx4g">
#        GitHub
#       </span>
#       , Inc.
#      </li>
#      <li class="mr-3">
#       <a data-ga-click="Footer, go to terms, text:terms" href="https://github.com/site/terms">
#        Terms
#       </a>
#      </li>
#      <li class="mr-3">
#       <a data-ga-click="Footer, go to privacy, text:privacy" href="https://github.com/site/privacy">
#        Privacy
#       </a>
#      </li>
#      <li class="mr-3">
#       <a data-ga-click="Footer, go to security, text:security" href="https://help.github.com/articles/github-security/">
#        Security
#       </a>
#      </li>
#      <li class="mr-3">
#       <a data-ga-click="Footer, go to status, text:status" href="https://status.github.com/">
#        Status
#       </a>
#      </li>
#      <li>
#       <a data-ga-click="Footer, go to help, text:help" href="https://help.github.com">
#        Help
#       </a>
#      </li>
#     </ul>
#     <a aria-label="Homepage" class="footer-octicon" href="https://github.com" title="GitHub">
#      <svg aria-hidden="true" class="octicon octicon-mark-github" height="24" version="1.1" viewbox="0 0 16 16" width="24">
#       <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0 0 16 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd">
#       </path>
#      </svg>
#     </a>
#     <ul class="list-style-none d-flex flex-wrap ">
#      <li class="mr-3">
#       <a data-ga-click="Footer, go to contact, text:contact" href="https://github.com/contact">
#        Contact GitHub
#       </a>
#      </li>
#      <li class="mr-3">
#       <a data-ga-click="Footer, go to api, text:api" href="https://developer.github.com">
#        API
#       </a>
#      </li>
#      <li class="mr-3">
#       <a data-ga-click="Footer, go to training, text:training" href="https://training.github.com">
#        Training
#       </a>
#      </li>
#      <li class="mr-3">
#       <a data-ga-click="Footer, go to shop, text:shop" href="https://shop.github.com">
#        Shop
#       </a>
#      </li>
#      <li class="mr-3">
#       <a data-ga-click="Footer, go to blog, text:blog" href="https://blog.github.com">
#        Blog
#       </a>
#      </li>
#      <li>
#       <a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">
#        About
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="d-flex flex-justify-center pb-6">
#     <span class="f6 text-gray-light">
#     </span>
#    </div>
#   </div>
#   <div class="ajax-error-message flash flash-error" id="ajax-error-message">
#    <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#     <path d="M8.893 1.5c-.183-.31-.52-.5-.887-.5s-.703.19-.886.5L.138 13.499a.98.98 0 0 0 0 1.001c.193.31.53.501.886.501h13.964c.367 0 .704-.19.877-.5a1.03 1.03 0 0 0 .01-1.002L8.893 1.5zm.133 11.497H6.987v-2.003h2.039v2.003zm0-3.004H6.987V5.987h2.039v4.006z" fill-rule="evenodd">
#     </path>
#    </svg>
#    <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
#     <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#      <path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd">
#      </path>
#     </svg>
#    </button>
#    You can’t perform that action at this time.
#   </div>
#   <script crossorigin="anonymous" integrity="sha512-wIuAKDhvxe9wCaNR1tzCk3rtl+wXEWC28rmRpzmx0h98VEeWC6Y3xCWV1xAW6NP6eQQX+x8ZGhW6Sdut+mLRuw==" src="https://assets-cdn.github.com/assets/compat-a48960bafc17c30572990bbab3664e9c.js" type="application/javascript">
#   </script>
#   <script crossorigin="anonymous" integrity="sha512-uM69WMiXMBe+fHB1eUDOoIAILOyoqkWpoQuBK/UHhCfk2lLxfinKPu28i4+Iu+v3eoUiPJnAAbzKzvQjVJ8tWQ==" src="https://assets-cdn.github.com/assets/frameworks-c3a7cd038fac31dc42fd60a02fd6e01a.js" type="application/javascript">
#   </script>
#   <script async="async" crossorigin="anonymous" integrity="sha512-J9ggkJODJ8Ua+CPMtBArebcEiUI+6GcvnLyqDVaylIdZoAUlgNdS9m2X+kVLBpt+Cee4htjUXdelShyexO33oQ==" src="https://assets-cdn.github.com/assets/github-11bea62a1664fab08563fe8f49a24094.js" type="application/javascript">
#   </script>
#   <div class="js-stale-session-flash stale-session-flash flash flash-warn flash-banner d-none">
#    <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#     <path d="M8.893 1.5c-.183-.31-.52-.5-.887-.5s-.703.19-.886.5L.138 13.499a.98.98 0 0 0 0 1.001c.193.31.53.501.886.501h13.964c.367 0 .704-.19.877-.5a1.03 1.03 0 0 0 .01-1.002L8.893 1.5zm.133 11.497H6.987v-2.003h2.039v2.003zm0-3.004H6.987V5.987h2.039v4.006z" fill-rule="evenodd">
#     </path>
#    </svg>
#    <span class="signed-in-tab-flash">
#     You signed in with another tab or window.
#     <a href="">
#      Reload
#     </a>
#     to refresh your session.
#    </span>
#    <span class="signed-out-tab-flash">
#     You signed out in another tab or window.
#     <a href="">
#      Reload
#     </a>
#     to refresh your session.
#    </span>
#   </div>
#   <div class="facebox" id="facebox" style="display:none;">
#    <div class="facebox-popup">
#     <div aria-describedby="facebox-description" aria-labelledby="facebox-header" class="facebox-content" role="dialog">
#     </div>
#     <button aria-label="Close modal" class="facebox-close js-facebox-close" type="button">
#      <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#       <path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd">
#       </path>
#      </svg>
#     </button>
#    </div>
#   </div>
#   <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
#    <div class="Popover-message Popover-message--bottom-left Popover-message--large Box box-shadow-large" style="width:360px;">
#    </div>
#   </div>
#   <div class="sr-only" id="hovercard-aria-description">
#    Press h to open a hovercard with more details.
#   </div>
#  </body>
# </html>

# %%
tables = soup.find_all("table")

# %% [markdown]
# ### Found 47 tables

# %%
len(tables)
# Out:
# 47

# %% [markdown]
# ### The first table did not contain api information so lets remove it again

# %%
tables = tables[1:]

# %% [markdown]
# ### Create dictionary to store data from tables from html soup, using nested loop to take out contents of each table

# %%
dictionary = {"API":[],
             "DESC":[],
             "AUTH":[],
             "HTTPS":[],
             "CORS":[],
             "LINK":[]}



for dataset_index in range(len(tables)):
    dataset = tables[dataset_index]
    row_table_level = dataset.find("tbody").find_all("tr")
    
    for row in row_table_level:
        cells = row.find_all("td")
        
        for index in range(len(cells)):
            #print(dataset_index, index, cells[index])
            if index == 0:
                dictionary["API"].append(cells[index].text)
            elif index == 1:
                dictionary["DESC"].append(cells[index].text)
            elif index == 2:
                dictionary["AUTH"].append(cells[index].text)
            elif index == 3:
                dictionary["HTTPS"].append(cells[index].text)
            elif index == 4:
                dictionary["CORS"].append(cells[index].text)
            elif index == 5:
                dictionary["LINK"].append(cells[index].find("a").get("href"))

# %%
api_data = pandas.DataFrame(dictionary)

# %%
api_data
# Out:
#                                        API  \
# 0                                     Cats
# 1                                     Dogs
# 2                                  HTTPCat
# 3                                     IUCN
# 4                                 Movebank
# 5                                Petfinder
# 6                                RandomCat
# 7                                RandomDog
# 8                                RandomFox
# 9                             RescueGroups
# 10                            Shibe.Online
# 11                                 AniList
# 12                                   Jikan
# 13                                   Kitsu
# 14                           Studio Ghibli
# 15   AlienVault Open Threat Exchange (OTX)
# 16                                  Certly
# 17                    Google Safe Browsing
# 18                                Metacert
# 19                              VirusTotal
# 20                      Web Of Trust (WOT)
# 21                                 Behance
# 22                           Cooper Hewitt
# 23                                Dribbble
# 24                     Harvard Art Museums
# 25                              Iconfinder
# 26                                  Icons8
# 27                            Noun Project
# 28                             Rijksmuseum
# 29                           Bhagavad Gita
# ..                                     ...
# 519                                  Bitly
# 520                             ClickMeter
# 521                   Google URL Shortener
# 522                              Rebrandly
# 523          Brazilian Vehicles and Prices
# 524                       Kelley Blue Book
# 525                          Mercedes-Benz
# 526                                  NHTSA
# 527                 An API of Ice And Fire
# 528                    Breaking Bad Quotes
# 529                       Czech Television
# 530                            Dailymotion
# 531                    Open Movie Database
# 532                     Ron Swanson Quotes
# 533                                  SWAPI
# 534                                   TMDb
# 535                                   TVDB
# 536                                 TVMaze
# 537                                 Utelly
# 538                                  Vimeo
# 539                                YouTube
# 540                ClimaCell Micro Weather
# 541                               Dark Sky
# 542                            MetaWeather
# 543                              ODWeather
# 544                                 OpenUV
# 545                         OpenWeatherMap
# 546                            Storm Glass
# 547                             Weatherbit
# 548                         Yahoo! Weather
#
#                                                   DESC           AUTH HTTPS  \
# 0                         Pictures of cats from Tumblr             No   Yes
# 1                   Based on the Stanford Dogs Dataset             No   Yes
# 2                            Cat for every HTTP Status             No   Yes
# 3                  IUCN Red List of Threatened Species         apiKey    No
# 4               Movement and Migration data of animals             No   Yes
# 5                                             Adoption         apiKey   Yes
# 6                              Random pictures of cats             No   Yes
# 7                              Random pictures of dogs             No   Yes
# 8                             Random pictures of foxes             No   Yes
# 9                                             Adoption             No   Yes
# 10         Random pictures of Shibu Inu, cats or birds             No    No
# 11                          Anime discovery & tracking          OAuth   Yes
# 12                          Unofficial MyAnimeList API             No   Yes
# 13                            Anime discovery platform          OAuth   Yes
# 14                  Resources from Studio Ghibli films             No   Yes
# 15                            IP/domain/URL reputation         apiKey   Yes
# 16                         Certly Link/Domain Flagging         apiKey   Yes
# 17                         Google Link/Domain Flagging         apiKey   Yes
# 18                              Metacert Link Flagging         apiKey   Yes
# 19                        VirusTotal File/URL Analysis         apiKey   Yes
# 20                                  Website reputation         apiKey   Yes
# 21                                              Design         apiKey   Yes
# 22                           Smithsonian Design Museum         apiKey   Yes
# 23                                              Design          OAuth    No
# 24                                                 Art         apiKey    No
# 25                                               Icons         apiKey   Yes
# 26                                               Icons          OAuth   Yes
# 27                                               Icons          OAuth    No
# 28                                                 Art         apiKey   Yes
# 29                                  Bhagavad Gita text          OAuth   Yes
# ..                                                 ...            ...   ...
# 519                  URL shortener and link management          OAuth   Yes
# 520  Monitor, compare, and optimize your marketing ...         apiKey   Yes
# 521  Takes long URLs and squeezes them into fewer c...         apiKey   Yes
# 522     Custom URL shortener for sharing branded links         apiKey   Yes
# 523  Vehicles information from Fundação Instituto d...             No   Yes
# 524  Vehicle info, pricing, configuration, plus muc...         apiKey   Yes
# 525  Telematics data, remotely access vehicle funct...         apiKey   Yes
# 526  NHTSA Product Information Catalog and Vehicle ...             No   Yes
# 527                                Game Of Thrones API             No   Yes
# 528                           Some Breaking Bad quotes             No   Yes
# 529                           TV programme of Czech TV             No    No
# 530                          Dailymotion Developer API          OAuth   Yes
# 531                                  Movie information         apiKey   Yes
# 532                                         Television             No   Yes
# 533                              Star Wars Information             No   Yes
# 534                         Community-based movie data         apiKey   Yes
# 535                                    Television data         apiKey   Yes
# 536                                       TV Show Data             No    No
# 537        Check where a tv show or movie is available  X-Mashape-Key   Yes
# 538                                Vimeo Developer API          OAuth   Yes
# 539   Add YouTube functionality to your sites and apps          OAuth   Yes
# 540    Historical, real-time, and nowcast weather data         apiKey   Yes
# 541                                            Weather         apiKey   Yes
# 542                                            Weather             No   Yes
# 543                        Weather and weather webcams             No    No
# 544                        Real-time UV Index Forecast         apiKey   Yes
# 545                                            Weather         apiKey    No
# 546        Global marine weather from multiple sources         apiKey   Yes
# 547                                            Weather         apiKey   Yes
# 548                                            Weather         apiKey   Yes
#
#         CORS                                               LINK
# 0    Unknown                    https://thecatapi.com/docs.html
# 1    Unknown                           https://dog.ceo/dog-api/
# 2    Unknown                                  https://http.cat/
# 3    Unknown           http://apiv3.iucnredlist.org/api/v3/docs
# 4    Unknown       https://github.com/movebank/movebank-api-doc
# 5    Unknown     https://www.petfinder.com/developers/api-docs/
# 6        Yes                        https://aws.random.cat/meow
# 7        Yes                       https://random.dog/woof.json
# 8        Yes                        https://randomfox.ca/floof/
# 9    Unknown  https://userguide.rescuegroups.org/display/API...
# 10   Unknown                               http://shibe.online/
# 11   Unknown      https://github.com/AniList/ApiV2-GraphQL-Docs
# 12       Yes                                  https://jikan.moe
# 13   Unknown                       http://docs.kitsu.apiary.io/
# 14   Unknown                    https://ghibliapi.herokuapp.com
# 15   Unknown                    https://otx.alienvault.com/api/
# 16   Unknown                           https://guard.certly.io/
# 17   Unknown       https://developers.google.com/safe-browsing/
# 18   Unknown                              https://metacert.com/
# 19   Unknown  https://www.virustotal.com/en/documentation/pu...
# 20   Unknown                     https://www.mywot.com/wiki/API
# 21   Unknown                        https://www.behance.net/dev
# 22   Unknown            https://collection.cooperhewitt.org/api
# 23   Unknown                  http://developer.dribbble.com/v1/
# 24   Unknown      https://github.com/harvardartmuseums/api-docs
# 25   Unknown                   https://developer.iconfinder.com
# 26   Unknown     http://docs.icons8.apiary.io/#reference/0/meta
# 27   Unknown           http://api.thenounproject.com/index.html
# 28   Unknown                  https://www.rijksmuseum.nl/en/api
# 29       Yes                        https://bhagavadgita.io/api
# ..       ...                                                ...
# 519  Unknown              http://dev.bitly.com/get_started.html
# 520  Unknown  https://support.clickmeter.com/hc/en-us/catego...
# 521  Unknown  https://developers.google.com/url-shortener/v1...
# 522  Unknown           https://developers.rebrandly.com/v1/docs
# 523  Unknown              https://deividfortuna.github.io/fipe/
# 524       No         http://developer.kbb.com/#!/data/1-Default
# 525       No           https://developer.mercedes-benz.com/apis
# 526  Unknown                    https://vpic.nhtsa.dot.gov/api/
# 527  Unknown                     https://anapioficeandfire.com/
# 528  Unknown    https://github.com/shevabam/breaking-bad-quotes
# 529  Unknown        http://www.ceskatelevize.cz/xml/tv-program/
# 530  Unknown                 https://developer.dailymotion.com/
# 531  Unknown                            http://www.omdbapi.com/
# 532  Unknown  https://github.com/jamesseanwright/ron-swanson...
# 533  Unknown                                   https://swapi.co
# 534  Unknown       https://www.themoviedb.org/documentation/api
# 535  Unknown                    https://api.thetvdb.com/swagger
# 536  Unknown                          http://www.tvmaze.com/api
# 537  Unknown           https://market.mashape.com/utelly/utelly
# 538  Unknown                       https://developer.vimeo.com/
# 539  Unknown             https://developers.google.com/youtube/
# 540      Yes                     https://developer.climacell.co
# 541       No                           https://darksky.net/dev/
# 542       No                   https://www.metaweather.com/api/
# 543  Unknown       http://api.oceandrivers.com/static/docs.html
# 544  Unknown                              https://www.openuv.io
# 545  Unknown                      http://openweathermap.org/api
# 546      Yes                             https://stormglass.io/
# 547  Unknown                      https://www.weatherbit.io/api
# 548  Unknown               https://developer.yahoo.com/weather/
#
# [549 rows x 6 columns]

# %% [markdown]
# ### Grab subset of api_data where auth is not required

# %%
subset_no = api_data[api_data["AUTH"] == "No"]
subset_no
# Out:
#                                      API  \
# 0                                   Cats
# 1                                   Dogs
# 2                                HTTPCat
# 4                               Movebank
# 6                              RandomCat
# 7                              RandomDog
# 8                              RandomFox
# 9                           RescueGroups
# 10                          Shibe.Online
# 12                                 Jikan
# 14                         Studio Ghibli
# 30                            BookNomads
# 31         British National Bibliography
# 34                          Open Library
# 35                    Penguin Publishing
# 37                         Clearbit Logo
# 38                        Domainsdb.info
# 42                             markerapi
# 43                               Ticksel
# 45                       Church Calendar
# 46               Czech Namedays Calendar
# 48                       Hebrew Calendar
# 50                             LectServe
# 51                     Namedays Calendar
# 52                      Non-Working Days
# 53                      Russian Calendar
# 64                         BitcoinCharts
# 69                            Blockchain
# 72                               CoinBin
# 73                              CoinDesk
# ..                                   ...
# 485  Transport for Auckland, New Zealand
# 486                Transport for Belgium
# 487        Transport for Berlin, Germany
# 488             Transport for Boston, US
# 489      Transport for Budapest, Hungary
# 490            Transport for Chicago, US
# 491         Transport for Czech Republic
# 492             Transport for Denver, US
# 493                Transport for Finland
# 495       Transport for Grenoble, France
# 497        Transport for London, England
# 501                 Transport for Norway
# 502         Transport for Ottawa, Canada
# 503          Transport for Paris, France
# 504          Transport for Paris, France
# 505       Transport for Philadelphia, US
# 508            Transport for Switzerland
# 511        Transport for The Netherlands
# 512        Transport for Toronto, Canada
# 513          Transport for United States
# 523        Brazilian Vehicles and Prices
# 526                                NHTSA
# 527               An API of Ice And Fire
# 528                  Breaking Bad Quotes
# 529                     Czech Television
# 532                   Ron Swanson Quotes
# 533                                SWAPI
# 536                               TVMaze
# 542                          MetaWeather
# 543                            ODWeather
#
#                                                   DESC AUTH HTTPS     CORS  \
# 0                         Pictures of cats from Tumblr   No   Yes  Unknown
# 1                   Based on the Stanford Dogs Dataset   No   Yes  Unknown
# 2                            Cat for every HTTP Status   No   Yes  Unknown
# 4               Movement and Migration data of animals   No   Yes  Unknown
# 6                              Random pictures of cats   No   Yes      Yes
# 7                              Random pictures of dogs   No   Yes      Yes
# 8                             Random pictures of foxes   No   Yes      Yes
# 9                                             Adoption   No   Yes  Unknown
# 10         Random pictures of Shibu Inu, cats or birds   No    No  Unknown
# 12                          Unofficial MyAnimeList API   No   Yes      Yes
# 14                  Resources from Studio Ghibli films   No   Yes  Unknown
# 30   Books published in the Netherlands and Flander...   No   Yes  Unknown
# 31                                               Books   No    No  Unknown
# 34                Books, book covers, and related data   No   Yes  Unknown
# 35                Books, book covers, and related data   No   Yes  Unknown
# 37   Search for company logos and embed them in you...   No   Yes  Unknown
# 38                      Registered Domain Names Search   No   Yes  Unknown
# 42                                    Trademark Search   No    No  Unknown
# 43          Friendly website analytics made for humans   No   Yes  Unknown
# 45                        Catholic liturgical calendar   No    No  Unknown
# 46          Lookup for a name and returns nameday date   No    No  Unknown
# 48   Convert between Gregarian and Hebrew, fetch Sh...   No    No  Unknown
# 50                      Protestant liturgical calendar   No    No  Unknown
# 51            Provides namedays for multiple countries   No   Yes      Yes
# 52          Database of ICS files for non working days   No   Yes  Unknown
# 53         Check if a date is a Russian holiday or not   No   Yes       No
# 64   Financial and Technical Data related to the Bi...   No   Yes  Unknown
# 69          Bitcoin Payment, Wallet & Transaction Data   No   Yes  Unknown
# 72                          Cryptocurrency information   No   Yes  Unknown
# 73                                 Bitcoin Price Index   No    No  Unknown
# ..                                                 ...  ...   ...      ...
# 485                                 Auckland Transport   No   Yes  Unknown
# 486                              Belgian transport API   No   Yes  Unknown
# 487                                Third-party VBB API   No   Yes  Unknown
# 488                                           MBTA API   No    No  Unknown
# 489                      Budapest public transport API   No   Yes  Unknown
# 490                                                CTA   No    No  Unknown
# 491                                Czech transport API   No   Yes  Unknown
# 492                                                RTD   No    No  Unknown
# 493                              Finnish transport API   No   Yes  Unknown
# 495                          Grenoble public transport   No    No       No
# 497                                            TfL API   No   Yes  Unknown
# 501                            Norwegian transport API   No    No  Unknown
# 502                    OC Transpo next bus arrival API   No    No  Unknown
# 503                                 RATP Open Data API   No    No  Unknown
# 504                         Live schedules made simple   No    No  Unknown
# 505                                         SEPTA APIs   No    No  Unknown
# 508                         Swiss public transport API   No   Yes  Unknown
# 511               OVAPI, country-wide public transport   No   Yes  Unknown
# 512                                                TTC   No   Yes  Unknown
# 513                                        NextBus API   No    No  Unknown
# 523  Vehicles information from Fundação Instituto d...   No   Yes  Unknown
# 526  NHTSA Product Information Catalog and Vehicle ...   No   Yes  Unknown
# 527                                Game Of Thrones API   No   Yes  Unknown
# 528                           Some Breaking Bad quotes   No   Yes  Unknown
# 529                           TV programme of Czech TV   No    No  Unknown
# 532                                         Television   No   Yes  Unknown
# 533                              Star Wars Information   No   Yes  Unknown
# 536                                       TV Show Data   No    No  Unknown
# 542                                            Weather   No   Yes       No
# 543                        Weather and weather webcams   No    No  Unknown
#
#                                                   LINK
# 0                      https://thecatapi.com/docs.html
# 1                             https://dog.ceo/dog-api/
# 2                                    https://http.cat/
# 4         https://github.com/movebank/movebank-api-doc
# 6                          https://aws.random.cat/meow
# 7                         https://random.dog/woof.json
# 8                          https://randomfox.ca/floof/
# 9    https://userguide.rescuegroups.org/display/API...
# 10                                http://shibe.online/
# 12                                   https://jikan.moe
# 14                     https://ghibliapi.herokuapp.com
# 30                      https://www.booknomads.com/dev
# 31                              http://bnb.data.bl.uk/
# 34              https://openlibrary.org/developers/api
# 35   http://www.penguinrandomhouse.biz/webservices/...
# 37                  https://clearbit.com/docs#logo-api
# 38                             https://domainsdb.info/
# 42                           http://www.markerapi.com/
# 43                                 https://ticksel.com
# 45                      http://calapi.inadiutorium.cz/
# 46                          http://svatky.adresa.info/
# 48          https://www.hebcal.com/home/developer-apis
# 50                            http://www.lectserve.com
# 51                             https://api.abalin.net/
# 52                     https://github.com/gadael/icsdb
# 53               https://github.com/egno/work-calendar
# 64          https://bitcoincharts.com/about/exchanges/
# 69                     https://www.blockchain.info/api
# 72                                https://coinbin.org/
# 73                        http://www.coindesk.com/api/
# ..                                                 ...
# 485                            https://api.at.govt.nz/
# 486                        https://hello.irail.be/api/
# 487  https://github.com/derhuerst/vbb-rest/blob/mas...
# 488     http://realtime.mbta.com/Portal/Home/Documents
# 489                                 https://apiary.io/
# 490          http://www.transitchicago.com/developers/
# 491    https://www.chaps.cz/eng/products/idos-internet
# 492  http://www.rtd-denver.com/gtfs-developer-guide...
# 493              https://digitransit.fi/en/developers/
# 495  https://www.metromobilite.fr/pages/opendata/Op...
# 497                             https://api.tfl.gov.uk
# 501                       http://reisapi.ruter.no/help
# 502      http://www.octranspo.com/index.php/developers
# 503  http://data.ratp.fr/api/v1/console/datasets/1....
# 504       http://restratpws.azurewebsites.net/swagger/
# 505                   http://www3.septa.org/hackathon/
# 508                     https://transport.opendata.ch/
# 511    https://github.com/skywave/KV78Turbo-OVAPI/wiki
# 512                        https://myttc.ca/developers
# 513  http://www.nextbus.com/xmlFeedDocs/NextBusXMLF...
# 523              https://deividfortuna.github.io/fipe/
# 526                    https://vpic.nhtsa.dot.gov/api/
# 527                     https://anapioficeandfire.com/
# 528    https://github.com/shevabam/breaking-bad-quotes
# 529        http://www.ceskatelevize.cz/xml/tv-program/
# 532  https://github.com/jamesseanwright/ron-swanson...
# 533                                   https://swapi.co
# 536                          http://www.tvmaze.com/api
# 542                   https://www.metaweather.com/api/
# 543       http://api.oceandrivers.com/static/docs.html
#
# [257 rows x 6 columns]
