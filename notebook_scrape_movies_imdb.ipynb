# %% [markdown]
# # Scrape movie data from IMDB

# %% [markdown]
# ## Import modules

# %%
import requests
import bs4
import pandas
import datetime

# %% [markdown]
# ## Set movies to pull
#
# - A multiple of 50.
# - There are 50 movies per page.

# %%
to_pull = 150

# %%
pages = int(to_pull / 50)

# %%
pages
# Out:
# 3

# %% [markdown]
# ## Create genres list

# %%
url = "https://www.imdb.com/search/title?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=b9121fa8-b7bb-4a3e-8887-aab822e0b5a7&pf_rd_r=M7EN5FCB22Q4BM2PT32C&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=moviemeter&genres=sci_fi&explore=title_type,genres&sort=user_rating,desc&page=1&title_type=tvMovie&view=advanced&ref_=adv_explore_rhs"
soup = bs4.BeautifulSoup(requests.get(url).text, 'lxml')
genres = soup.find("div", {"class":"aux-content-widget-2"})
links = genres.find_all("a")

genre_list = []

for link in links:
    href = link.get("href")
    broken_down = href.split("&")
    for item in broken_down:
        if "genres=" in item:
            if item not in genre_list:
                genre_list.append(item)
                
for index in range(len(genre_list)):
    print(index, genre_list[index])
# Out:
# 0 genres=sci_fi
# 1 genres=Sci-Fi
# 2 genres=Action
# 3 genres=Drama
# 4 genres=Thriller
# 5 genres=Horror
# 6 genres=Adventure
# 7 genres=Comedy
# 8 genres=Fantasy
# 9 genres=Animation
# 10 genres=Family
# 11 genres=Mystery
# 12 genres=Documentary
# 13 genres=Romance
# 14 genres=Crime
# 15 genres=Musical
# 16 genres=Music
# 17 genres=War
# 18 genres=History
# 19 genres=Sport
# 20 genres=Western
# 21 genres=Biography
# 22 genres=Reality-TV
# 23 genres=Talk-Show
# 24 genres=News
# 25 genres=Game-Show

# %% [markdown]
# ## Set pages list

# %%
pages_list = list(range(1,pages+1))

# %%
pages_list
# Out:
# [1, 2, 3]

# %% [markdown]
# ##  Set genre parameters list

# %%
genre_parameters_list = [genre_list[14], genre_list[13], genre_list[7]]

# %% [markdown]
# ## Create dictionary to store data

# %%
movie_dictionary = {
    "year":[],
    "title":[],
    "index":[],
    "rating":[],
    "number_votes":[],
    "runtime":[],
    "genre":[],
    "url_genre":[],
    "description":[],
    "date_extracted":[]
}

# %%
date = datetime.datetime.now()

# %%
clean_year_chars = "1234567890"

# %% [markdown]
# ## Process

# %%
for genre_parameter in genre_parameters_list:
    for page_number in pages_list:

        url = "https://www.imdb.com/search/title?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=b9121fa8-b7bb-4a3e-8887-aab822e0b5a7&pf_rd_r=M7EN5FCB22Q4BM2PT32C&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=moviemeter&"+ genre_parameter + "&explore=title_type,genres&sort=user_rating,desc&page=" + str(page_number) + "&view=advanced&title_type=tvMovie&ref_=adv_explore_rhs"

        request = requests.get(url)
        soup = bs4.BeautifulSoup(request.text,"lxml")
        movies = soup.find_all("div", {"class":"lister-item"})

        for movie in movies:

            #year
            year = movie.find("span", {"class":"lister-item-year"}).text.strip()
            for char in year:
                if char not in clean_year_chars:
                    year = year.replace(char, "")

            year = int(year)

            #title
            title = movie.find("h3", {"class":"lister-item-header"}).find("a").text.strip()

            #index
            rank = movie.find("span",{"class":"lister-item-index"}).text.strip()

            #rating
            rating = movie.find("div", {"class":"inline-block"}).get("data-value")

            #number votes
            votes = movie.find("span", {"name":"nv"}).get("data-value")

            #runtime
            try:
                runtime = movie.find("span", {"class":"runtime"}).text.strip()
            except:
                runtime = None

            #genre
            genre = movie.find_all("span", {"class":"genre"})[0].text.strip()

            #description
            desc = movie.find_all("p", {"class":"text-muted"})[1].text.strip()

            #store
            movie_dictionary["year"].append(year)
            movie_dictionary["title"].append(title)
            movie_dictionary["index"].append(rank)
            movie_dictionary["rating"].append(rating)
            movie_dictionary["number_votes"].append(votes)
            movie_dictionary["runtime"].append(runtime)
            movie_dictionary["genre"].append(genre)
            movie_dictionary["url_genre"].append(genre_parameter)
            movie_dictionary["description"].append(desc)
            movie_dictionary["date_extracted"].append(date)

# %% [markdown]
# ## Store dictionary in pandas dataframe

# %%
data = pandas.DataFrame(movie_dictionary)

# %%
data
# Out:
#      year                                     title index rating number_votes  \
# 0    1954                      Zwischenfall im Roxy    1.     10            6
# 1    1964                    Usluga tacna i solidna    2.     10            9
# 2    1960                    Natjecaj za crnu pricu    3.    9.9            9
# 3    1965                        Party im Zwielicht    4.    9.8            5
# 4    1953                            Kopf oder Zahl    5.    9.6            7
# 5    1964                            Ein langer Tag    6.    9.6            5
# 6    1967               Das Attentat - L.D. Trotzki    7.    9.5           13
# 7    1965                             Sonata facile    8.    9.5           11
# 8    1966                            Die Ermittlung    9.    9.4           22
# 9    1981                          Ubohý pan Kufalt   10.    9.4            8
# 10   1964                                      Koll   11.    9.4            7
# 11   1964                   Maigret: De kruideniers   12.    9.4            5
# 12   1954              Mädchen mit dem Brokatmantel   13.    9.4            5
# 13   1993                       The Mike King Story   14.    9.4           75
# 14   1982                            Family in Blue   15.    9.3           19
# 15   1963                           Detective Story   16.    9.3            6
# 16   1961                               Vorsätzlich   17.    9.3           17
# 17   1979                                      Lulu   18.    9.2            8
# 18   2011                               Venice Heat   19.    9.2            5
# 19   1970            Wie man seinen Gatten los wird   20.    9.2            5
# 20   1962                                  Blizanci   21.    9.2           12
# 21   1961                          Zahlungsaufschub   22.    9.2           11
# 22   1961                                 Die Falle   23.    9.2           11
# 23   1968                Eine etwas sonderbare Dame   24.    9.2           12
# 24   1961                       Der Mann von drüben   25.    9.2           17
# 25   1987                                    Juarez   26.      9            8
# 26   2015                               Mr. Lockjaw   27.    9.1           13
# 27   1992                                    Casino   28.    9.1            8
# 28   1981                                  Hardcase   29.    9.1            8
# 29   1991                                  Dioskuri   30.    9.1           13
# ..    ...                                       ...   ...    ...          ...
# 420  2008                             Torn Up Tales  121.    9.2            5
# 421  1966                 Paris ist eine Reise wert  122.    9.2           17
# 422  2001                 Nokj sproti Sveti Vasilij  123.    9.2           20
# 423  1965                          Der müde Theodor  124.    9.2           23
# 424  2015                              Falling Flat  125.    9.2           22
# 425  1976                    Még mindig aktuális...  126.    9.2           41
# 426  1969                  Eine Frau ohne Bedeutung  127.    9.2           10
# 427  2007                             Mild Mannered  128.    9.2            5
# 428  1955                        Die Husaren kommen  129.    9.2           12
# 429  1962                           Protektionskind  130.    9.2            5
# 430  1964                                   Amouren  131.    9.2           10
# 431  2017                     The Christmas Hot Dog  132.    9.2            8
# 432  1961                 Das Rendezvous von Senlis  133.    9.2           13
# 433  1965                         Romulus der Große  134.    9.2           22
# 434  1958                                     Moral  135.    9.2            5
# 435  1985  The Honeymooners Anniversary Celebration  136.    9.2            5
# 436  1963             An Evening with Carol Burnett  137.    9.2           12
# 437  1982                             Qesh e ngjesh  138.    9.2            6
# 438  1970            Wie man seinen Gatten los wird  139.    9.2            5
# 439  1967                             Die Gefährtin  140.    9.2           11
# 440  1966                       Der doppelte Moritz  141.    9.2           11
# 441  1965                                   Colombe  142.    9.2           12
# 442  1982          All-Star Party for Carol Burnett  143.    9.2           67
# 443  2000                            Merely Players  144.    9.2           10
# 444  1982                      Nevezz csak Cucinak!  145.    9.2           46
# 445  1962                    Tratsch im Treppenhaus  146.    9.2           58
# 446  1997          Une mère comme on n'en fait plus  147.    9.2            5
# 447  1964                     Der Mitternachtsmarkt  148.    9.2           10
# 448  1963                         Ein besserer Herr  149.    9.2           12
# 449  1964             Der Kaiser vom Alexanderplatz  150.    9.2            6
#
#      runtime                     genre      url_genre  \
# 0     45 min                     Crime   genres=Crime
# 1       None                     Crime   genres=Crime
# 2       None                     Crime   genres=Crime
# 3     65 min              Crime, Drama   genres=Crime
# 4     45 min                     Crime   genres=Crime
# 5     51 min                     Crime   genres=Crime
# 6    155 min            Crime, History   genres=Crime
# 7     60 min                     Crime   genres=Crime
# 8    155 min              Crime, Drama   genres=Crime
# 9    185 min      Comedy, Crime, Drama   genres=Crime
# 10    45 min              Crime, Drama   genres=Crime
# 11      None                     Crime   genres=Crime
# 12      None                     Crime   genres=Crime
# 13    30 min                     Crime   genres=Crime
# 14      None     Action, Crime, Family   genres=Crime
# 15   105 min              Crime, Drama   genres=Crime
# 16    85 min                     Crime   genres=Crime
# 17   171 min       Crime, Drama, Music   genres=Crime
# 18    22 min             Comedy, Crime   genres=Crime
# 19   100 min             Comedy, Crime   genres=Crime
# 20      None                     Crime   genres=Crime
# 21    90 min                     Crime   genres=Crime
# 22    75 min                     Crime   genres=Crime
# 23    95 min                     Crime   genres=Crime
# 24    70 min              Crime, Drama   genres=Crime
# 25    60 min                     Crime   genres=Crime
# 26      None                     Crime   genres=Crime
# 27    90 min  Action, Adventure, Crime   genres=Crime
# 28    60 min            Crime, Mystery   genres=Crime
# 29      None                     Crime   genres=Crime
# ..       ...                       ...            ...
# 420     None           Comedy, Fantasy  genres=Comedy
# 421   80 min                    Comedy  genres=Comedy
# 422   88 min                    Comedy  genres=Comedy
# 423  104 min                    Comedy  genres=Comedy
# 424   35 min    Comedy, Music, Musical  genres=Comedy
# 425   41 min                    Comedy  genres=Comedy
# 426   63 min    Comedy, Drama, Romance  genres=Comedy
# 427   22 min                    Comedy  genres=Comedy
# 428   70 min                    Comedy  genres=Comedy
# 429  120 min                    Comedy  genres=Comedy
# 430   91 min                    Comedy  genres=Comedy
# 431   22 min                    Comedy  genres=Comedy
# 432  105 min                    Comedy  genres=Comedy
# 433   98 min                    Comedy  genres=Comedy
# 434   75 min                    Comedy  genres=Comedy
# 435   60 min                    Comedy  genres=Comedy
# 436   60 min            Family, Comedy  genres=Comedy
# 437     None            Comedy, Family  genres=Comedy
# 438  100 min             Comedy, Crime  genres=Comedy
# 439   60 min                    Comedy  genres=Comedy
# 440  125 min                    Comedy  genres=Comedy
# 441  105 min           Comedy, Romance  genres=Comedy
# 442   60 min             Comedy, Music  genres=Comedy
# 443   90 min             Comedy, Drama  genres=Comedy
# 444   48 min                    Comedy  genres=Comedy
# 445  120 min                    Comedy  genres=Comedy
# 446   90 min                    Comedy  genres=Comedy
# 447  105 min             Comedy, Music  genres=Comedy
# 448   70 min                    Comedy  genres=Comedy
# 449   88 min                    Comedy  genres=Comedy
#
#                                            description  \
# 0                                           Add a Plot
# 1                                           Add a Plot
# 2                                           Add a Plot
# 3                                           Add a Plot
# 4                                           Add a Plot
# 5                                           Add a Plot
# 6                                           Add a Plot
# 7                                           Add a Plot
# 8    This is a theatrical production on a cbs antho...
# 9                                           Add a Plot
# 10   After closing time, a man called Koll demands ...
# 11                                          Add a Plot
# 12                                          Add a Plot
# 13   Mike King unravels a drug cartel's smuggling o...
# 14                                          Add a Plot
# 15                                          Add a Plot
# 16                                          Add a Plot
# 17   Adaptation of the work of Wedekind which was a...
# 18   A squad of dysfunctional beach cops serve and ...
# 19                                          Add a Plot
# 20                                          Add a Plot
# 21                                          Add a Plot
# 22                                          Add a Plot
# 23                                          Add a Plot
# 24                                          Add a Plot
# 25   Pilot series about a Mexican-American sheriff'...
# 26   Mr. Lockjaw is an American drama series create...
# 27   A movie for television which was a pilot for a...
# 28   Lieutenant Grover Harding Case will do anythin...
# 29                                          Add a Plot
# ..                                                 ...
# 420  A modern, irreverent and funny re-telling of t...
# 421                                         Add a Plot
# 422                                         Add a Plot
# 423                                         Add a Plot
# 424  An indie rock band in the LA music scene try t...
# 425                                         Add a Plot
# 426                                         Add a Plot
# 427  Meet Jim, owner of a comic book shop and all a...
# 428                                         Add a Plot
# 429                                         Add a Plot
# 430                                         Add a Plot
# 431  The Egos come together in a plot to change Chr...
# 432                                         Add a Plot
# 433                                         Add a Plot
# 434                                         Add a Plot
# 435                                         Add a Plot
# 436                                         Add a Plot
# 437                                         Add a Plot
# 438                                         Add a Plot
# 439                                         Add a Plot
# 440                                         Add a Plot
# 441                                         Add a Plot
# 442                                         Add a Plot
# 443                                         Add a Plot
# 444                                         Add a Plot
# 445                                         Add a Plot
# 446                                         Add a Plot
# 447                                         Add a Plot
# 448                                         Add a Plot
# 449                                         Add a Plot
#
#                 date_extracted
# 0   2018-06-14 11:43:35.535828
# 1   2018-06-14 11:43:35.535828
# 2   2018-06-14 11:43:35.535828
# 3   2018-06-14 11:43:35.535828
# 4   2018-06-14 11:43:35.535828
# 5   2018-06-14 11:43:35.535828
# 6   2018-06-14 11:43:35.535828
# 7   2018-06-14 11:43:35.535828
# 8   2018-06-14 11:43:35.535828
# 9   2018-06-14 11:43:35.535828
# 10  2018-06-14 11:43:35.535828
# 11  2018-06-14 11:43:35.535828
# 12  2018-06-14 11:43:35.535828
# 13  2018-06-14 11:43:35.535828
# 14  2018-06-14 11:43:35.535828
# 15  2018-06-14 11:43:35.535828
# 16  2018-06-14 11:43:35.535828
# 17  2018-06-14 11:43:35.535828
# 18  2018-06-14 11:43:35.535828
# 19  2018-06-14 11:43:35.535828
# 20  2018-06-14 11:43:35.535828
# 21  2018-06-14 11:43:35.535828
# 22  2018-06-14 11:43:35.535828
# 23  2018-06-14 11:43:35.535828
# 24  2018-06-14 11:43:35.535828
# 25  2018-06-14 11:43:35.535828
# 26  2018-06-14 11:43:35.535828
# 27  2018-06-14 11:43:35.535828
# 28  2018-06-14 11:43:35.535828
# 29  2018-06-14 11:43:35.535828
# ..                         ...
# 420 2018-06-14 11:43:35.535828
# 421 2018-06-14 11:43:35.535828
# 422 2018-06-14 11:43:35.535828
# 423 2018-06-14 11:43:35.535828
# 424 2018-06-14 11:43:35.535828
# 425 2018-06-14 11:43:35.535828
# 426 2018-06-14 11:43:35.535828
# 427 2018-06-14 11:43:35.535828
# 428 2018-06-14 11:43:35.535828
# 429 2018-06-14 11:43:35.535828
# 430 2018-06-14 11:43:35.535828
# 431 2018-06-14 11:43:35.535828
# 432 2018-06-14 11:43:35.535828
# 433 2018-06-14 11:43:35.535828
# 434 2018-06-14 11:43:35.535828
# 435 2018-06-14 11:43:35.535828
# 436 2018-06-14 11:43:35.535828
# 437 2018-06-14 11:43:35.535828
# 438 2018-06-14 11:43:35.535828
# 439 2018-06-14 11:43:35.535828
# 440 2018-06-14 11:43:35.535828
# 441 2018-06-14 11:43:35.535828
# 442 2018-06-14 11:43:35.535828
# 443 2018-06-14 11:43:35.535828
# 444 2018-06-14 11:43:35.535828
# 445 2018-06-14 11:43:35.535828
# 446 2018-06-14 11:43:35.535828
# 447 2018-06-14 11:43:35.535828
# 448 2018-06-14 11:43:35.535828
# 449 2018-06-14 11:43:35.535828
#
# [450 rows x 10 columns]
